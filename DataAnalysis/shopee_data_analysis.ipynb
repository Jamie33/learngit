# %% [markdown]
# # 利用 python 对 shopee 印尼站四大品类商品进行数据分析
#
# ## 目录
#
# 1. [数据集概要](#数据集概要)
#
# 2. [预览数据](#预览数据)
#
# 3. [数据统计分析](#数据统计分析)
#
# 4. [数据可视化](#数据可视化)
#
#    1. [四大品类的商品数量占比](#四大品类的商品数量占比)
#
#       - [饰品分析](#饰品分析)
#       - [手表分析](#手表分析)
#
#    2. [四大品类的商品价格情况](#四大品类的商品价格分布)
#
#       - [价格分布](#价格分布)
#       - [价格峰值](#价格峰值)
#
#    3. [四大品类的商品销量情况](#四大品类的商品销量情况)
#
#       - [销量分布](#销量分布)
#       - [销量峰值](#销量峰值)
# ---
#
# ## 数据集概要
#
# 这次数据集的基本信息：
#
# - 数据集大小：311条
#
# - 平台： Shopee
#
# - 品类：男鞋，手表，男包，饰品
#
# - 筛选标准：月销量超过1500的商品
#
# - 汇率：1 Rp = 0.0005 RMB
#
# - 时间：2019.03.14
#
# > 数据集来源：shopee_sales_1500_0305.csv
#
# ---
#
# ## 预览数据
#
# 预览数据集前10行数据

# %%
import numpy as np
import pandas as pd

data_file = 'shopee_sales_1500_0305.csv'
data = pd.read_csv(data_file)
data.head(10)
# Out:
#    category  main class                                          item name  \
# 0  MenShoes     Sandals                     Sandal slop kokop bulu rashfur
# 1  MenShoes     Sandals  Sandal (sendal) Masjid Musholla Wudhu Wakaf Se...
# 2  MenShoes     Sandals      Arsy Sandal Gunung Slop / Sandal Pria - Hitam
# 3  MenShoes    Sneakers         Sepatu Adidas Italy New Edition Size 39-43
# 4  MenShoes    Sneakers                      NIKE AIRMAX NEW EDITION 39-43
# 5  MenShoes    Sneakers                         NEW ADIDAS RUNNING NEO MAN
# 6  MenShoes    Sneakers  Sepatu Converse All Star The Best Quality + BO...
# 7  MenShoes    Sneakers            IMPORT SEPATU V TALI PRIA !!! - 3 WARNA
# 8  MenShoes    Sneakers  Sepatu Nike V2 Zoom Running New Edition Size 3...
# 9   Watches  MenWatches  Jam Tangan Q&Q Jelly Angka Rubber Transparant ...
#
#           price info    price  monthly sales  \
# 0             Rp5500   5500.0           2665
# 1             Rp7000   7000.0           2275
# 2  Rp14900 - Rp24900  19900.0           1563
# 3            Rp34000  34000.0           3119
# 4            Rp45500  45500.0           2478
# 5            Rp45500  45500.0           2553
# 6            Rp53000  53000.0           2083
# 7            Rp79000  79000.0           1895
# 8            Rp34000  34000.0           1883
# 9  Rp12000 - Rp12800  12400.0          50660
#
#                                             item url  \
# 0  https://shopee.co.id/Sandal-slop-kokop-bulu-ra...
# 1  https://shopee.co.id/Sandal-(sendal)-Masjid-Mu...
# 2  https://shopee.co.id/Arsy-Sandal-Gunung-Slop-S...
# 3  https://shopee.co.id/Sepatu-Adidas-Italy-New-E...
# 4  https://shopee.co.id/NIKE-AIRMAX-NEW-EDITION-3...
# 5  https://shopee.co.id/NEW-ADIDAS-RUNNING-NEO-MA...
# 6  https://shopee.co.id/Sepatu-Converse-All-Star-...
# 7  https://shopee.co.id/IMPORT-SEPATU-V-TALI-PRIA...
# 8  https://shopee.co.id/Sepatu-Nike-V2-Zoom-Runni...
# 9  https://shopee.co.id/Jam-Tangan-Q-Q-Jelly-Angk...
#
#                                         item picture
# 0  https://cf.shopee.co.id/file/d76c5c7b9583f8ece...
# 1  https://cf.shopee.co.id/file/d094b5a9bdb5736f3...
# 2  https://cf.shopee.co.id/file/28bd1c01c1ea85a05...
# 3  https://cf.shopee.co.id/file/12b052746c735fc65...
# 4  https://cf.shopee.co.id/file/6346fedd27e8fb0b5...
# 5  https://cf.shopee.co.id/file/34b1094419ed8c218...
# 6  https://cf.shopee.co.id/file/6526d93fbb2ed10ac...
# 7  https://cf.shopee.co.id/file/178c052db514fb59c...
# 8  https://cf.shopee.co.id/file/4f28cf7e985333761...
# 9  https://cf.shopee.co.id/file/93ddf26de1c5e258f...

# %% [markdown]
# **注意**
# - price info：商品价格信息
# - price: 如果商品有价格区间，price 为价格低点和价格高点的平均值
#
# ---
#
# ## 数据统计分析

# %%
import numpy as np
import pandas as pd
from PIL import Image

currency_rate = 0.0005
print('\n---------------数据集统计分析------------------\n')

fields = data.columns.tolist()
print('数据集来源：{}'.format(data_file))
print('正在统计分析数据集......')
print('数据集字段: {}'.format(fields))
category_name = data['category'].unique()
print('数据集大分类: {}'.format(category_name ))
print('数据集小分类: {}'.format(data['main class'].unique()))
data_section = data[['category','main class','price','monthly sales']]
data_name = ['价格','月销量','商品数量','最高销量','小分类']

print('\n---------------类别统计分析-------------------\n')

# 统计大分类是 MenShoes 的数据
print('正在统计 {0[0]} 的数据: {1[0]}，{1[1]}，{1[2]}，{1[3]}，{1[4]} ......'.format(category_name,data_name))
menshoes = data_section[data_section['category'] == 'MenShoes']
menshoes_pricelist = menshoes['price']* currency_rate
print(type(menshoes['price']))
menshoes_saleslist = menshoes['monthly sales']
menshoes_num = menshoes.count()
menshoes_salesmax = max(menshoes_saleslist)

# 统计大分类是 Watches 的数据
print('正在统计 {0[1]} 的数据: {1[0]}，{1[1]}，{1[2]}，{1[3]}，{1[4]} ......'.format(category_name,data_name))
watches = data_section[data_section['category'] == 'Watches']
watches_pricelist = watches['price']* currency_rate
watches_saleslist = watches['monthly sales']
watches_num = watches.count()
watches_salesmax = max(watches_saleslist)
watches_class = watches['main class'].unique()
watches_class_num = [len(watches[watches['main class'] == i]) for i in watches_class ]

# 统计大分类是 Menbags 的数据
print('正在统计 {0[2]} 的数据: {1[0]}，{1[1]}，{1[2]}，{1[3]}，{1[4]} ......'.format(category_name,data_name))
menbags = data_section[data_section['category'] == 'Menbags']
menbags_pricelist = menbags['price']* currency_rate
menbags_saleslist = menbags['monthly sales']
menbags_num =  menbags.count()
menbags_salesmax = max(menbags_saleslist)

# 统计大分类是 Fashion 的数据
print('正在统计 {0[3]} 的数据: {1[0]}，{1[1]}，{1[2]}，{1[3]}，{1[4]} ......'.format(category_name,data_name))
fashion = data_section[data_section['category'] == 'Fashion']
fashion_pricelist = fashion['price']* currency_rate
fashion_saleslist = fashion['monthly sales']
fashion_num = fashion.count()
fashion_salesmax = max(fashion_saleslist)
fashion_class = fashion['main class'].unique()
fashion_class_num = [len(fashion[fashion['main class'] == i]) for i in fashion_class ]
# Out:
# ---------------数据集统计分析------------------
#
# 数据集来源：shopee_sales_1500_0305.csv
# 正在统计分析数据集......
# 数据集字段: ['category', 'main class', 'item name', 'price info', 'price', 'monthly sales', 'item url', 'item picture']
# 数据集大分类: ['MenShoes' 'Watches' 'Menbags' 'Fashion']
# 数据集小分类: ['Sandals' 'Sneakers' 'MenWatches' 'WomenWatches' 'CoupleWatches'
#  'Backpacks' 'SlingBags' 'WaistBags' 'Shoulder Bags' 'MenWallet'
#  'HairAccessories' 'Hats' 'Glasses' 'ContactLenses' 'Earrings' 'Necklaces'
#  'Rings' 'Bracelets' 'Belts' 'Scarf' 'AccessoriesSets']
#
# ---------------类别统计分析-------------------
#
# 正在统计 MenShoes 的数据: 价格，月销量，商品数量，最高销量，小分类 ......
# <class 'pandas.core.series.Series'>
# 正在统计 Watches 的数据: 价格，月销量，商品数量，最高销量，小分类 ......
# 正在统计 Menbags 的数据: 价格，月销量，商品数量，最高销量，小分类 ......
# 正在统计 Fashion 的数据: 价格，月销量，商品数量，最高销量，小分类 ......

# %% [markdown]
# ---
#
# ## 数据可视化
#
# ### 四大品类的商品数量占比

# %%
from pyecharts import Pie
from pyecharts import online
online()

pie = Pie('Category percentage',title_pos='center')
pie.add('Item Number',category_name,[menshoes_num,watches_num,menbags_num,fashion_num],radius=[40, 70],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="left")
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9f1aca0fa07a4cf68adaf9a0c7661103" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9f1aca0fa07a4cf68adaf9a0c7661103 = echarts.init(document.getElementById('9f1aca0fa07a4cf68adaf9a0c7661103'), 'light', {renderer: 'canvas'});
#
# var option_9f1aca0fa07a4cf68adaf9a0c7661103 = {
#     "title": [
#         {
#             "text": "Category percentage",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5637115,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "Item Number",
#             "data": [
#                 {
#                     "name": "MenShoes",
#                     "value": [
#                         9.0,
#                         9.0,
#                         9.0,
#                         9.0
#                     ]
#                 },
#                 {
#                     "name": "Watches",
#                     "value": [
#                         117.0,
#                         117.0,
#                         117.0,
#                         117.0
#                     ]
#                 },
#                 {
#                     "name": "Menbags",
#                     "value": [
#                         20.0,
#                         20.0,
#                         20.0,
#                         20.0
#                     ]
#                 },
#                 {
#                     "name": "Fashion",
#                     "value": [
#                         165.0,
#                         165.0,
#                         165.0,
#                         165.0
#                     ]
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 5637115
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "MenShoes",
#                 "Watches",
#                 "Menbags",
#                 "Fashion"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_9f1aca0fa07a4cf68adaf9a0c7661103.setOption(option_9f1aca0fa07a4cf68adaf9a0c7661103);
#
#     });
# </script>

# %% [markdown]
# 男鞋，手表，男包，饰品四大品类中月销量超过1500的商品
#
# - 饰品和手表数量占多数，分别是53.06%, 37.62%,其中**饰品**最多：165条
# - 男鞋和男包数量占少数，分别是6.43%, 2.89%,其中**男鞋**最少：9条
#
#
# 下面主要分析饰品和手表
#
# #### 饰品分析

# %%
from pyecharts import Pie

pie = Pie('Fashion accessories',title_pos='center')
pie.add('Item number',fashion_class,fashion_class_num,radius=[40, 70],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="Left")
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b26e32d0157c4abfa5d74102c1b775fd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b26e32d0157c4abfa5d74102c1b775fd = echarts.init(document.getElementById('b26e32d0157c4abfa5d74102c1b775fd'), 'light', {renderer: 'canvas'});
#
# var option_b26e32d0157c4abfa5d74102c1b775fd = {
#     "title": [
#         {
#             "text": "Fashion accessories",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6096684,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "Item number",
#             "data": [
#                 {
#                     "name": "HairAccessories",
#                     "value": 12
#                 },
#                 {
#                     "name": "Hats",
#                     "value": 7
#                 },
#                 {
#                     "name": "Glasses",
#                     "value": 60
#                 },
#                 {
#                     "name": "ContactLenses",
#                     "value": 54
#                 },
#                 {
#                     "name": "Earrings",
#                     "value": 1
#                 },
#                 {
#                     "name": "Necklaces",
#                     "value": 4
#                 },
#                 {
#                     "name": "Rings",
#                     "value": 1
#                 },
#                 {
#                     "name": "Bracelets",
#                     "value": 4
#                 },
#                 {
#                     "name": "Belts",
#                     "value": 4
#                 },
#                 {
#                     "name": "Scarf",
#                     "value": 3
#                 },
#                 {
#                     "name": "AccessoriesSets",
#                     "value": 15
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 6096684
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "HairAccessories",
#                 "Hats",
#                 "Glasses",
#                 "ContactLenses",
#                 "Earrings",
#                 "Necklaces",
#                 "Rings",
#                 "Bracelets",
#                 "Belts",
#                 "Scarf",
#                 "AccessoriesSets"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "Left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_b26e32d0157c4abfa5d74102c1b775fd.setOption(option_b26e32d0157c4abfa5d74102c1b775fd);
#
#     });
# </script>

# %% [markdown]
# 饰品包括：眼镜，隐形眼镜/美瞳，首饰套装，头饰，帽子，项链，手镯，腰带，围巾/丝巾，戒子，耳环
#
# 其中：**眼镜，隐形眼镜/美瞳 **占比最高
#
# #### 手表分析

# %%
from pyecharts import Pie

pie = Pie('Watches',title_pos='center')
pie.add('Item number',watches_class,watches_class_num,radius=[40, 70],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="Left")
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="870c94005787406984cc1b7bb8557249" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_870c94005787406984cc1b7bb8557249 = echarts.init(document.getElementById('870c94005787406984cc1b7bb8557249'), 'light', {renderer: 'canvas'});
#
# var option_870c94005787406984cc1b7bb8557249 = {
#     "title": [
#         {
#             "text": "Watches",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8290331,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "Item number",
#             "data": [
#                 {
#                     "name": "MenWatches",
#                     "value": 22
#                 },
#                 {
#                     "name": "WomenWatches",
#                     "value": 79
#                 },
#                 {
#                     "name": "CoupleWatches",
#                     "value": 16
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8290331
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "MenWatches",
#                 "WomenWatches",
#                 "CoupleWatches"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "Left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_870c94005787406984cc1b7bb8557249.setOption(option_870c94005787406984cc1b7bb8557249);
#
#     });
# </script>

# %% [markdown]
# 手表款式包括：女表，男表，情侣表
#
# 其中：**女表**占比最高

# %% [markdown]
# ### 四大品类的商品价格情况
#
# #### 价格分布

# %%
from pyecharts import Scatter

scatter = Scatter('Price distribution','Menshoes-Watches-Menbags-Fashion')
scatter.add('MenShoes',menshoes_saleslist,menshoes_pricelist,xaxis_name ='sales',yaxis_name = 'price (rmb)',yaxis_name_gap=50,xaxis_min=1500)
scatter.add('Watches',watches_saleslist,watches_pricelist,xaxis_name ='sales',yaxis_name = 'price (rmb)',yaxis_name_gap=50,xaxis_min=1500)
scatter.add('Menbags',menbags_saleslist,menbags_pricelist,xaxis_name ='sales',yaxis_name = 'price (rmb)',yaxis_name_gap=50,xaxis_min=1500)
scatter.add('Fashion',fashion_saleslist,fashion_pricelist,xaxis_name ='sales',yaxis_name = 'price (rmb)',yaxis_name_gap=50,xaxis_min=1500)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f1c978d8be9f4992a7074d53aff778ae" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f1c978d8be9f4992a7074d53aff778ae = echarts.init(document.getElementById('f1c978d8be9f4992a7074d53aff778ae'), 'light', {renderer: 'canvas'});
#
# var option_f1c978d8be9f4992a7074d53aff778ae = {
#     "title": [
#         {
#             "text": "Price distribution",
#             "subtext": "Menshoes-Watches-Menbags-Fashion",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8173083,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "MenShoes",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     2665,
#                     2.75
#                 ],
#                 [
#                     2275,
#                     3.5
#                 ],
#                 [
#                     1563,
#                     9.950000000000001
#                 ],
#                 [
#                     3119,
#                     17.0
#                 ],
#                 [
#                     2478,
#                     22.75
#                 ],
#                 [
#                     2553,
#                     22.75
#                 ],
#                 [
#                     2083,
#                     26.5
#                 ],
#                 [
#                     1895,
#                     39.5
#                 ],
#                 [
#                     1883,
#                     17.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8173083
#         },
#         {
#             "type": "scatter",
#             "name": "Watches",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     50660,
#                     6.2
#                 ],
#                 [
#                     7489,
#                     34.25
#                 ],
#                 [
#                     5496,
#                     4.399
#                 ],
#                 [
#                     3674,
#                     34.0
#                 ],
#                 [
#                     4028,
#                     5.75
#                 ],
#                 [
#                     3883,
#                     6.0
#                 ],
#                 [
#                     2889,
#                     9.5
#                 ],
#                 [
#                     2750,
#                     32.016
#                 ],
#                 [
#                     2574,
#                     9.305
#                 ],
#                 [
#                     4529,
#                     33.5
#                 ],
#                 [
#                     2914,
#                     3.15
#                 ],
#                 [
#                     2495,
#                     6.5
#                 ],
#                 [
#                     2378,
#                     4.399
#                 ],
#                 [
#                     1999,
#                     31.3
#                 ],
#                 [
#                     1951,
#                     14.0
#                 ],
#                 [
#                     2476,
#                     3.85
#                 ],
#                 [
#                     1985,
#                     75.0
#                 ],
#                 [
#                     1755,
#                     32.5
#                 ],
#                 [
#                     1741,
#                     0.375
#                 ],
#                 [
#                     1693,
#                     6.5
#                 ],
#                 [
#                     2048,
#                     4.399
#                 ],
#                 [
#                     2069,
#                     8.75
#                 ],
#                 [
#                     19445,
#                     13.75
#                 ],
#                 [
#                     16368,
#                     7.25
#                 ],
#                 [
#                     14587,
#                     24.0
#                 ],
#                 [
#                     15987,
#                     4.865
#                 ],
#                 [
#                     19283,
#                     5.7
#                 ],
#                 [
#                     24620,
#                     5.15
#                 ],
#                 [
#                     12982,
#                     5.5
#                 ],
#                 [
#                     12399,
#                     4.399
#                 ],
#                 [
#                     13868,
#                     9.5
#                 ],
#                 [
#                     16684,
#                     5.6000000000000005
#                 ],
#                 [
#                     12137,
#                     6.25
#                 ],
#                 [
#                     11896,
#                     6.25
#                 ],
#                 [
#                     9643,
#                     26.0
#                 ],
#                 [
#                     9788,
#                     6.2
#                 ],
#                 [
#                     7538,
#                     6.7
#                 ],
#                 [
#                     6786,
#                     5.5
#                 ],
#                 [
#                     5961,
#                     9.25
#                 ],
#                 [
#                     6002,
#                     4.865
#                 ],
#                 [
#                     5264,
#                     25.85
#                 ],
#                 [
#                     4395,
#                     13.0
#                 ],
#                 [
#                     4490,
#                     11.4
#                 ],
#                 [
#                     3945,
#                     9.25
#                 ],
#                 [
#                     3933,
#                     6.4
#                 ],
#                 [
#                     4397,
#                     6.2
#                 ],
#                 [
#                     4114,
#                     5.075
#                 ],
#                 [
#                     3472,
#                     7.5
#                 ],
#                 [
#                     3830,
#                     12.450000000000001
#                 ],
#                 [
#                     3433,
#                     6.3500000000000005
#                 ],
#                 [
#                     3647,
#                     6.71
#                 ],

# %% [markdown]
# - 男鞋 价格分布在0-40元之间
# - 手表 价格集中在0-20元之间
# - 男包 价格集中在10-30元之间
# - 饰品 价格集中在0-20元之间
#
# #### 价格峰值

# %%
from pyecharts import Boxplot

boxplot = Boxplot('Price peak')
x_axis = data['category'].unique()
y_axis = [menshoes_pricelist,watches_pricelist,menbags_pricelist,fashion_pricelist]
boxplot.add("price", x_axis, boxplot.prepare_data(y_axis))
num = 0
for box in boxplot.prepare_data(y_axis):
    print(x_axis[num])
    print("min 最小值:{0[0]} / Q1下四分位数:{0[1]} / median(or Q2)中位数:{0[2]} / Q3上四分位数:{0[3]} / max最大值:{0[4]}".format(box,x_axis))
    num += 1
boxplot
# Out:
# MenShoes
# min 最小值:2.75 / Q1下四分位数:6.7250000000000005 / median(or Q2)中位数:17.0 / Q3上四分位数:24.625 / max最大值:39.5
# Watches
# min 最小值:0.375 / Q1下四分位数:5.75 / median(or Q2)中位数:7.1000000000000005 / Q3上四分位数:12.725000000000001 / max最大值:75.0
# Menbags
# min 最小值:9.0 / Q1下四分位数:11.25 / median(or Q2)中位数:20.775000000000002 / Q3上四分位数:28.0625 / max最大值:50.0
# Fashion
# min 最小值:0.2 / Q1下四分位数:3.4000000000000004 / median(or Q2)中位数:5.95 / Q3上四分位数:11.2625 / max最大值:51.23075
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="773c0ff194b045abafa4b91354643ab0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_773c0ff194b045abafa4b91354643ab0 = echarts.init(document.getElementById('773c0ff194b045abafa4b91354643ab0'), 'light', {renderer: 'canvas'});
#
# var option_773c0ff194b045abafa4b91354643ab0 = {
#     "title": [
#         {
#             "text": "Price peak",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5419863,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "price",
#             "data": [
#                 [
#                     2.75,
#                     6.7250000000000005,
#                     17.0,
#                     24.625,
#                     39.5
#                 ],
#                 [
#                     0.375,
#                     5.75,
#                     7.1000000000000005,
#                     12.725000000000001,
#                     75.0
#                 ],
#                 [
#                     9.0,
#                     11.25,
#                     20.775000000000002,
#                     28.0625,
#                     50.0
#                 ],
#                 [
#                     0.2,
#                     3.4000000000000004,
#                     5.95,
#                     11.2625,
#                     51.23075
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5419863
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "price"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "MenShoes",
#                 "Watches",
#                 "Menbags",
#                 "Fashion"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_773c0ff194b045abafa4b91354643ab0.setOption(option_773c0ff194b045abafa4b91354643ab0);
#
#     });
# </script>

# %% [markdown]
# - 男鞋 最高价格 39.5 元
# - 手表 最高价格 75 元
# - 男包 最高价格 50 元
# - 饰品 最高价格 51 元
#
# ### 四大品类的商品销量情况
#
# #### 销量分布

# %%
from pyecharts import Scatter

scatter = Scatter('Sales distribution','Menshoes-Watches-Menbags-Fashion')
scatter.add('MenShoes',menshoes_pricelist,menshoes_saleslist,yaxis_name ='sales',xaxis_name = 'price (rmb)',yaxis_name_gap=50,yaxis_min=1500)
scatter.add('Watches',watches_pricelist,watches_saleslist,yaxis_name ='sales',xaxis_name = 'price (rmb)',yaxis_name_gap=50,yaxis_min=1500)
scatter.add('Menbags',menbags_pricelist,menbags_saleslist,yaxis_name ='sales',xaxis_name = 'price (rmb)',yaxis_name_gap=50,yaxis_min=1500)
scatter.add('Fashion',fashion_pricelist,fashion_saleslist,yaxis_name ='sales',xaxis_name = 'price (rmb)',yaxis_name_gap=50,yaxis_min=1500)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="52d784eb22e045809bb624cdd9691f81" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_52d784eb22e045809bb624cdd9691f81 = echarts.init(document.getElementById('52d784eb22e045809bb624cdd9691f81'), 'light', {renderer: 'canvas'});
#
# var option_52d784eb22e045809bb624cdd9691f81 = {
#     "title": [
#         {
#             "text": "Sales distribution",
#             "subtext": "Menshoes-Watches-Menbags-Fashion",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7528901,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "MenShoes",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     2.75,
#                     2665
#                 ],
#                 [
#                     3.5,
#                     2275
#                 ],
#                 [
#                     9.950000000000001,
#                     1563
#                 ],
#                 [
#                     17.0,
#                     3119
#                 ],
#                 [
#                     22.75,
#                     2478
#                 ],
#                 [
#                     22.75,
#                     2553
#                 ],
#                 [
#                     26.5,
#                     2083
#                 ],
#                 [
#                     39.5,
#                     1895
#                 ],
#                 [
#                     17.0,
#                     1883
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7528901
#         },
#         {
#             "type": "scatter",
#             "name": "Watches",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     6.2,
#                     50660
#                 ],
#                 [
#                     34.25,
#                     7489
#                 ],
#                 [
#                     4.399,
#                     5496
#                 ],
#                 [
#                     34.0,
#                     3674
#                 ],
#                 [
#                     5.75,
#                     4028
#                 ],
#                 [
#                     6.0,
#                     3883
#                 ],
#                 [
#                     9.5,
#                     2889
#                 ],
#                 [
#                     32.016,
#                     2750
#                 ],
#                 [
#                     9.305,
#                     2574
#                 ],
#                 [
#                     33.5,
#                     4529
#                 ],
#                 [
#                     3.15,
#                     2914
#                 ],
#                 [
#                     6.5,
#                     2495
#                 ],
#                 [
#                     4.399,
#                     2378
#                 ],
#                 [
#                     31.3,
#                     1999
#                 ],
#                 [
#                     14.0,
#                     1951
#                 ],
#                 [
#                     3.85,
#                     2476
#                 ],
#                 [
#                     75.0,
#                     1985
#                 ],
#                 [
#                     32.5,
#                     1755
#                 ],
#                 [
#                     0.375,
#                     1741
#                 ],
#                 [
#                     6.5,
#                     1693
#                 ],
#                 [
#                     4.399,
#                     2048
#                 ],
#                 [
#                     8.75,
#                     2069
#                 ],
#                 [
#                     13.75,
#                     19445
#                 ],
#                 [
#                     7.25,
#                     16368
#                 ],
#                 [
#                     24.0,
#                     14587
#                 ],
#                 [
#                     4.865,
#                     15987
#                 ],
#                 [
#                     5.7,
#                     19283
#                 ],
#                 [
#                     5.15,
#                     24620
#                 ],
#                 [
#                     5.5,
#                     12982
#                 ],
#                 [
#                     4.399,
#                     12399
#                 ],
#                 [
#                     9.5,
#                     13868
#                 ],
#                 [
#                     5.6000000000000005,
#                     16684
#                 ],
#                 [
#                     6.25,
#                     12137
#                 ],
#                 [
#                     6.25,
#                     11896
#                 ],
#                 [
#                     26.0,
#                     9643
#                 ],
#                 [
#                     6.2,
#                     9788
#                 ],
#                 [
#                     6.7,
#                     7538
#                 ],
#                 [
#                     5.5,
#                     6786
#                 ],
#                 [
#                     9.25,
#                     5961
#                 ],
#                 [
#                     4.865,
#                     6002
#                 ],
#                 [
#                     25.85,
#                     5264
#                 ],
#                 [
#                     13.0,
#                     4395
#                 ],
#                 [
#                     11.4,
#                     4490
#                 ],
#                 [
#                     9.25,
#                     3945
#                 ],
#                 [
#                     6.4,
#                     3933
#                 ],
#                 [
#                     6.2,
#                     4397
#                 ],
#                 [
#                     5.075,
#                     4114
#                 ],
#                 [
#                     7.5,
#                     3472
#                 ],
#                 [
#                     12.450000000000001,
#                     3830
#                 ],
#                 [
#                     6.3500000000000005,
#                     3433
#                 ],
#                 [
#                     6.71,
#                     3647
#                 ],

# %% [markdown]
# - 男鞋 销量分布在 1500-3119 件之间
# - 手表 销量集中在 1500-10000 件之间
# - 男包 销量集中在 1500-4000 件之间
# - 饰品 销量集中在 1500-10000 件之间
#
# #### 销量峰值

# %%
from pyecharts import Boxplot

boxplot = Boxplot('Sales peak')
x_axis = data['category'].unique()
y_axis = [menshoes_saleslist,watches_saleslist,menbags_saleslist,fashion_saleslist]
boxplot.add("sales", x_axis, boxplot.prepare_data(y_axis))
num = 0
for box in boxplot.prepare_data(y_axis):
    print(x_axis[num])
    print("min 最小值:{0[0]} / Q1下四分位数:{0[1]} / median(or Q2)中位数:{0[2]} / Q3上四分位数:{0[3]} / max最大值:{0[4]}".format(box,x_axis))
    num += 1
boxplot
# Out:
# MenShoes
# min 最小值:1563 / Q1下四分位数:1889.0 / median(or Q2)中位数:2275 / Q3上四分位数:2609.0 / max最大值:3119
# Watches
# min 最小值:1538 / Q1下四分位数:1933.0 / median(or Q2)中位数:2750 / Q3上四分位数:4396.0 / max最大值:50660
# Menbags
# min 最小值:1536 / Q1下四分位数:1834.5 / median(or Q2)中位数:2373.5 / Q3上四分位数:3007.0 / max最大值:13768
# Fashion
# min 最小值:1500 / Q1下四分位数:2035.5 / median(or Q2)中位数:2651 / Q3上四分位数:4325.5 / max最大值:63504
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="15947ec78bc845fa92e3f9878ea80055" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_15947ec78bc845fa92e3f9878ea80055 = echarts.init(document.getElementById('15947ec78bc845fa92e3f9878ea80055'), 'light', {renderer: 'canvas'});
#
# var option_15947ec78bc845fa92e3f9878ea80055 = {
#     "title": [
#         {
#             "text": "Sales peak",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3122306,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "sales",
#             "data": [
#                 [
#                     1563,
#                     1889.0,
#                     2275,
#                     2609.0,
#                     3119
#                 ],
#                 [
#                     1538,
#                     1933.0,
#                     2750,
#                     4396.0,
#                     50660
#                 ],
#                 [
#                     1536,
#                     1834.5,
#                     2373.5,
#                     3007.0,
#                     13768
#                 ],
#                 [
#                     1500,
#                     2035.5,
#                     2651,
#                     4325.5,
#                     63504
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3122306
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sales"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "MenShoes",
#                 "Watches",
#                 "Menbags",
#                 "Fashion"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_15947ec78bc845fa92e3f9878ea80055.setOption(option_15947ec78bc845fa92e3f9878ea80055);
#
#     });
# </script>

# %% [markdown]
# - 男鞋 最高销量 3119 件
# - 手表 最高销量 50660 件
# - 男包 最高销量 13768 件
# - 饰品 最高销量 63504 件
