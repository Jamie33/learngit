# %% [markdown]
# 豆瓣小组分类贴

# %%
from selenium import webdriver
import datetime,time
from pyquery import PyQuery as pq
import requests
from PIL import Image
from io import BytesIO

def douban(username,password,page):

    url = 'https://accounts.douban.com/login'
    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(url) # 访问网页
    try:
        response = requests.get(driver.find_element_by_id('captcha_image').get_attribute('src'))
        image = Image.open(BytesIO(response.content))
        image.show()
        code =input()
        time.sleep(7)
        driver.find_element_by_id('captcha_field').send_keys(code)
    except:
        pass
    driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
    driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
    driver.find_element_by_name('login').submit() # 点击登陆按钮
    content = '小组前10页全部翻译类汇总，贴出来供大家参考,不定期更新\n' 
    
    for n in range(0,page*25+1,25):
        task_url = 'https://www.douban.com/group/484299/discussion?start={}'.format(n)    
        driver.get(task_url)
        doc = pq(task_url)
        threads = doc('.olt').find('.title a')
        for i in threads.items():
            thread_name = i.attr('title')
            thread_url = i.attr('href')
            if '翻译' in thread_name:
                content = content+thread_name+'\n'+thread_url+'\n\n'

    print(content)
    driver.quit() # 退出浏览器
        
    
username = '' # 你的账号
password = '' # 你的密码
page = 10 # 页数
douban(username,password,page)
# Out:
# 小组前10页全部翻译类汇总，贴出来供大家参考,不定期更新
# 吐糟&在线翻译，每小时轻松50+
# https://www.douban.com/group/topic/125135027/
#
# 深圳龙华翻译：我想和你一起用心折腾这个老院子
# https://www.douban.com/group/topic/128621206/
#
# 【靠谱兼职】英语字幕翻译
# https://www.douban.com/group/topic/97502066/
#
# 招募翻译在线兼职
# https://www.douban.com/group/topic/71655088/
#
# 招兼职翻译！！
# https://www.douban.com/group/topic/129042335/
#
# 【兼职信息分类导航】小组前10页全部翻译类汇总
# https://www.douban.com/group/topic/128759474/
#
# 翻译兼职赚外快
# https://www.douban.com/group/topic/71002449/
#
# 招英文简历翻译，中翻英，量大长期
# https://www.douban.com/group/topic/108872316/
#
# 留下微信 拉你进翻译兼职群 欢迎大家加入
# https://www.douban.com/group/topic/90880209/
#
# 长期招聘翻译兼职
# https://www.douban.com/group/topic/125077964/
#
# 热头咁晒，喺家企做下粤语语音翻译啦！
# https://www.douban.com/group/topic/121828009/
#
# 兼职：阿拉伯语翻译
# https://www.douban.com/group/topic/128962581/
#
# 澳洲翻译公司招聘长期合作专业中英笔译员（地点不限）
# https://www.douban.com/group/topic/121910386/
#
# 诚招有中英专利摘要翻译经验的小伙伴，长期有稿件，待遇优厚
# https://www.douban.com/group/topic/110909612/
#
# 【远程兼职】视频翻译、微博运营、短文案、视频剪辑
# https://www.douban.com/group/topic/107863278/
#
# 招募英语视频字幕翻译，特别简单
# https://www.douban.com/group/topic/124685218/
#
# 【工作机会】兼职翻译招募
# https://www.douban.com/group/topic/128764364/
#
# 翻译任务
# https://www.douban.com/group/topic/91476459/
#
# 招聘银行制度文件类英语兼职翻译
# https://www.douban.com/group/topic/78294143/
#
# 招英语兼职翻译
# https://www.douban.com/group/topic/106791823/
#
# 翻译公司招兼职翻译及留学文书写手！
# https://www.douban.com/group/topic/127885828/
#
# ★★★长期招聘英语兼职翻译★★★
# https://www.douban.com/group/topic/110635533/
#
# 汉语言文学专业，通过CATTI笔译三级，寻找一份兼职翻译的工作
# https://www.douban.com/group/topic/122492786/

# %% [markdown]
# 小组帖子置顶回应

# %%
 # 编辑帖子
    thread_edit = thread_url+'edit'
    driver.get(thread_edit) 
    time.sleep(7)
    container = driver.find_element_by_css_selector('div.DRE-unstyled.DRE-left')
    container.clear()
    container.send_keys(content)
    time.sleep(7)
# Out:
# 小组前10页全部翻译类汇总，贴出来供大家参考,不定期更新
# adsfasdf

# %%
from selenium import webdriver
import datetime,time
from pyquery import PyQuery as pq
import requests
from PIL import Image
from io import BytesIO

def douban(username,password,thread_url,content):

    url = 'https://accounts.douban.com/login'
    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(url) # 访问网页
    try: 
        response = requests.get(driver.find_element_by_id('captcha_image').get_attribute('src'))
        image = Image.open(BytesIO(response.content))
        image.show()
        time.sleep(7)
        code =input() 
        driver.find_element_by_id('captcha_field').send_keys(code)
    except:
        pass
    driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
    driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
    
    driver.find_element_by_name('login').submit() # 点击登陆按钮
    
    # 回复帖子
    
    driver.get(thread_url) 
    time.sleep(7)
    driver.find_element_by_name('rv_comment').send_keys(content) # 回复帖子
    driver.implicitly_wait(5)  # 隐式等待
    driver.find_element_by_name('submit_btn').click() # 点击提交

    print('本帖已于{}更新'.format(datetime.datetime.now()))

    driver.quit() # 退出浏览器
        
    
username = '' # 你的账号
password = '' # 你的密码
thread_url = 'https://www.douban.com/group/topic/128759474/'
content = '本帖已更新'

douban(username,password,thread_url,content)
# Out:
# 本帖已于2018-12-03 10:51:26.696204更新

# %%
from selenium import webdriver
import datetime,time
from pyquery import PyQuery as pq
import requests
from PIL import Image
from io import BytesIO

def douban(username,password,thread_url,content):

    url = 'https://accounts.douban.com/login'
    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(url) # 访问网页
    response = requests.get(driver.find_element_by_id('captcha_image').get_attribute('src'))
    image = Image.open(BytesIO(response.content))
    image.show()
    code =input() 
    time.sleep(7)
    driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
    driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
    driver.find_element_by_id('captcha_field').send_keys(code)
    driver.find_element_by_name('login').submit() # 点击登陆按钮
    
    # 编辑帖子
    
    thread_edit = thread_url + 'edit'
    driver.get(thread_url) 
    time.sleep(7)
    

    print('本帖已于{}编辑'.format(datetime.datetime.now()))

    driver.quit() # 退出浏览器
        
    
username = '' # 你的账号
password = '' # 你的密码
thread_url = 'https://www.douban.com/group/topic/128759474/'
content = '本帖已更新'

douban(username,password,thread_url,content)

# %% [markdown]
# 豆瓣小组列表

# %%
from selenium import webdriver
import datetime,time
from pyquery import PyQuery as pq
import requests
from PIL import Image
from io import BytesIO

def group_list(url,group_url,username,password,page):

    
    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(url) # 访问网页
    try:
        response = requests.get(driver.find_element_by_id('captcha_image').get_attribute('src'))
        image = Image.open(BytesIO(response.content))
        image.show()
        code =input()
        time.sleep(7)
        driver.find_element_by_id('captcha_field').send_keys(code)
    except:
        pass
    
    driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
    driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
    driver.find_element_by_name('login').submit() # 点击登陆按钮
    
    
    for i in range(0,page*20,20):
        group_link = group_url.format(i)
        driver.get(group_link)
        doc = pq(group_link)
        results = doc('.groups').find('.title a')
        for i in results.items():
            thread_name = i.text()
            thread_url = i.attr('href')
            print(thread_name,thread_url)
            groups = [i.attr('href')+'discussion?start=0' for i in results.items()]
            
    return(groups)
    driver.quit() # 退出浏览器
        
    
username = '' # 你的账号
password = '' # 你的密码
url = 'https://accounts.douban.com/login'
group_url = 'https://www.douban.com/group/search?start={}&cat=1019&sort=relevance&q=%E7%BF%BB%E8%AF%91%E5%85%BC%E8%81%8C'
page = 2 # 页数



group_list(url,group_url,username,password,page)
# Out:
# second
# 豆瓣稿费银行：征稿 兼职 翻译 编剧 https://www.douban.com/group/TGYGXZ/
# 兼职翻译平台 https://www.douban.com/group/564823/
# 兼职翻译（上海地区） https://www.douban.com/group/484301/
# 兼职翻译（深圳、广州地区） https://www.douban.com/group/484299/
# 兼职俄语翻译 https://www.douban.com/group/525871/
# 北京兼职翻译-英语+小语种+中文 https://www.douban.com/group/568776/
# 北京兼职翻译 https://www.douban.com/group/563982/
# 上海价值译翻译公司招兼职 https://www.douban.com/group/338847/
# 北京♥翻译兼职♥自由译者♥招聘 https://www.douban.com/group/589374/
# 兼职翻译（成都地区） https://www.douban.com/group/484303/
# 北京兼职翻译-英语+小语种+中文 https://www.douban.com/group/568775/
# 中翻英兼职翻译招聘啦 https://www.douban.com/group/588323/
# 外语兼职翻译社 https://www.douban.com/group/maxtrip/
# 小语种兼职翻译 https://www.douban.com/group/590507/
# 天津兼职翻译 https://www.douban.com/group/572272/
# 语言桥兼职翻译小组 https://www.douban.com/group/625033/
# 口译兼职 https://www.douban.com/group/367450/
# 翻译公司 https://www.douban.com/group/545560/
# 我译网Wiitrans https://www.douban.com/group/581239/
# 翻译求职 https://www.douban.com/group/560922/
# 翻译工作机会 https://www.douban.com/group/586555/
# ['https://www.douban.com/group/586555/']

# %%
from selenium import webdriver
import datetime,time
from pyquery import PyQuery as pq
import requests
from PIL import Image
from io import BytesIO

def douban(url,username,password,page,thread_url):


    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(url) # 访问网页
    try:
        response = requests.get(driver.find_element_by_id('captcha_image').get_attribute('src'))
        image = Image.open(BytesIO(response.content))
        image.show()
        code =input()
        time.sleep(7)
        driver.find_element_by_id('captcha_field').send_keys(code)
    except:
        pass
    driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
    driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
    driver.find_element_by_name('login').submit() # 点击登陆按钮
    
    
    for n in range(0,page*25+1,25):
        thread_url = 'https://www.douban.com/group/484299/discussion?start={}'.format(n)    
        driver.get(thread_ur)
        doc = pq(thread_ur)
        threads = doc('.olt').find('.title a')
        for i in threads.items():
            thread_name = i.attr('title')
            thread_url = i.attr('href')
            if '翻译' in thread_name:
                print(thread_name+'\n'+thread_url+'\n\n')

 
    driver.quit() # 退出浏览器
        
    
username = '' # 你的账号
password = '' # 你的密码
page = 10 # 页数
url = 'https://accounts.douban.com/login'
thread_url = 'https://www.douban.com/group/560922/discussion?start=0'

douban(url,username,password,page,thread_url)
# Out:
# 0
# 20
