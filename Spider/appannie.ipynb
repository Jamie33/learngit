# %%
from selenium import webdriver
import time
from pyquery import PyQuery as pq

def appann(username,password,rank_url):
    with open('annie_googleplayshopping.csv','a',encoding='utf-8') as w:
        url = 'https://www.appannie.com/account/login/?_ref=header'
        driver = webdriver.Chrome()  #声明浏览器对象
        driver.get(url) # 访问网页
        driver.find_element_by_id('email').send_keys(username) # 提取账号输入框，并输入用户名
        driver.find_element_by_id('password').send_keys(password) # 提取密码输入框，并输入密码
        driver.find_element_by_id('submit').submit() # 点击登陆按钮 
        driver.get(rank_url) # 访问网页
        time.sleep(5)
        content =driver.find_elements_by_css_selector('tr.main-row.table-row')
        for i in content:
            name = i.find_element_by_css_selector('.app-link').text
            company_name = i.find_element_by_css_selector('.company-link').text.replace(',','')
            print(name,company_name)
            w.write('{},{}\n'.format(name,company_name))
            
username = '' # 你的账号
password = '' # 你的密码
rank_url  ='https://www.appannie.com/apps/google-play/top-chart/?country=JP&category=30&device=&date=2018-11-30&feed=All&rank_sorting_type=rank&page_number=0&page_size=100&table_selections='
appann(username,password,rank_url)
appann(username,password,rank_url)
# Out:
# ｄポイントクラブ NTT DOCOMO
# フリマアプリ「メルカリ」オークションよりかんたん Mercari
# Amazon Shopping Amazon
# 楽天市場 いつでもポイント+1倍 Rakuten
# ラクマ（旧フリル） - 満足度No.1 楽天のフリマアプリ Rakuten
# ヤフオク! -ネットオークション、フリマアプリ スマホでかんたんショッピング Yahoo Japan
# Yahoo!ショッピング-アプリでお得で便利にお買い物 Yahoo Japan
# 地元でゆずりあい　ジモティー　掲載料0円手数料0円！無料で、ラクに、すぐに処分できる掲示板 Jimoty
# ヤマダ電機　ケイタイde安心 Nihon Unisys
# ファッション通販 ZOZOTOWN ZOZO Inc.
# 電子マネー「nanaco」 Seven Card Service
# Wish - Shopping Made Fun ContextLogic
# Qoo10-今日のコスパを掘り出そう!いつでもお得にお買い物 eBay Japan G.K
# ノジマ Nojima
# Wowma! Wow!なイベント毎日開催! 通販ショッピングアプリ KDDI Commerce Forward
# 楽天Edy：ポイントがドンドン貯まる便利でお得な電子マネー Rakuten
# minne - ハンドメイドマーケットアプリ GMO Pepabo
# ファッション通販ショッピングSHOPLIST-ショップリスト CROOZ
# ハンドメイドマーケットアプリ - Creema（クリーマ） Creema
# 亚马逊 HD Amazon
# レシートがお金にかわるアプリCODE リサーチ・アンド・イノベーション
# 靴＆ファッション通販 - LOCONDO.jp (ロコンド) LOCONDO
# 洋服の青山アプリ AOYAMA TRADING
# ビックカメラ BICCAMERA
# モバオク　手数料無料の簡単オークションアプリ・フリマアプリ Mobaoku
# [.st] Adastria
# ヨドバシ YODOBASHI CAMERA
# BUYMA(バイマ) - 海外ファッション通販アプリ 日本語であんしん取引 保証も充実 ENIGMO
# BASE（ベイス）- 60万店舗から探せる通販・ショッピングアプリ　ハンドメイドやベビー用品も BASE Inc
# WAON AEON
# JRE POINT アプリ - JR東日本の共通ポイント East Japan Railway Company
# マルチ残高リーダFree /Suicaやnanacoなど対応 Shekeen
# 公式コメリドットコム Bit-A Co.Ltd.
# 洋服レンタル「メチャカリ」全て新品 今すぐ1ヶ月無料体験 STRIPE INTERNATIONAL
# 條碼掃描器 ZXing Team
# Amazon Prime Now Amazon
# iDアプリ （MVNO/SIMロックフリー端末版） NTT DOCOMO
# サイクルベースあさひの自転車アプリ ASAHI CO.LTD.
# 価格.com Kakaku.com
# サンプル百貨店-商品をお得に試せるちょっプル All About Life Marketing Inc.
# パンパース：すくすくポイントで、赤ちゃんとママパパへのギフトをもらおう！ Pampers by P&G
# 西友 - SEIYU - SEIYU
# Groupon Groupon
# ハンズクラブアプリ Tokyu Hands
# トイザらス・ベビーザらス アプリ Toys "R" Us
# オムニ7アプリ Seven & I Holdings
# ROOM　すきなモノが見つかる楽天のショッピングアプリ Rakuten
# 割引計算電卓 あぷりカンパニー。
# Nike SNKRS Nike
# tutuanna (チュチュアンナ) 公式アプリ TuTuanna
# ポンパレモール リクルートの通販 いつでもポイント3％以上！ Recruit Holdings
# ロハコ - ショッピングアプリ　日用品通販LOHACO ASKUL Corporation
# AliExpress - Smarter Shopping, Better Living Alibaba
# くらしのマーケット minma Inc.
# ブランド品のフリマアプリ「KANTE（カンテ）」 Komehyo Co. Ltd
# ディズニーストアクラブ Disney
# Amazon Assistant Amazon
# マザウェイズ公式アプリ motherways Co. Ltd.
# BOOTH―同人誌、グッズのショッピングアプリ pixiv
# IKEA Store IKEA
# ココナラ(coconala) - 得意を売り買い スキルのフリマ coconala inc.
# POCKET PARCO お部屋で、電車で、カフェで、好きなものが見つかる、買える。 PARCO
# ローソンフレッシュピック - 野菜やお肉が今日揃う Lawson Inc
# オタマート - オタクグッズに最適なアニメのフリマアプリ A Inc.
# 事業者向け通販【モノタロウ】 - 現場で使う消耗品をアプリで注文！ MonotaRO Co.Ltd
# 许多卡 Stocard - 会员卡 Stocard
# 人気バッグ！サマンサ公式アプリ！ Samantha Thavasa Japan Limited
# QUICPay JCB
# iHerb iHerb
# Design Tshirts Store graniph Design Tshirts Store graniph
# Right-on ライトオン公式アプリ Right-on
# Banggood - Easy Online Shopping Banggood
# WEGO公式アプリ WEGO Co.Ltd.
# ドスパラ - チェックインポイントや割引クーポンがもらえる！ 株式会社サードウェーブ
# ハニーズアプリ HONEYS. Co. Ltd.
# コジマ コジマ公式アプリ
# イオン九州公式アプリ イオン九州株式会社
# ニッセン-買い物アプリ-カタログ通販でレディースファッション・コスメ・家具・インテリアをショッピング Nissen
# 通販カタログ「フェリシモ」の通販・ショッピングアプリ。インテリアやキッチン用品まで扱う人気通販アプリ FELISSIMO
# Tahoe 免費 QR Code 掃描器 Tahoe Digital LTD.
# トリンプ☆下着メーカーTriumphの公式アプリ☆ トリンプ・インターナショナル・ジャパン株式会社
# JAVA members club レディースファッション ジャヴァコーポレーション
# ジャパネットたかた JAPANET TAKATA Co.Ltd.
# 简单快捷的计算折扣小工具。 DEEBEE
# FANCLメンバーズ ＦＡＮＣＬ
# THE SUIT COMPANY & UNIVERSAL+ AOYAMA TRADING
# SAC'S BAR（サックスバー）公式アプリ TOKYO DERICA CO.LTD.
# Qoo10ショッピング for Tablet eBay Japan G.K
# 楽天市場&ヤフーショッピング同時検索 RENAVE INC.
# 伊勢丹STOREアプリ Isetan
# コープこうべアプリ 生活協同組合コープこうべ
# 楽天ブックス-本・漫画・DVD・CDの通販アプリ Rakuten
# Tabioアプリ Tabio
# Supreme Supreme New York
# チケット流通センター 安心安全 かんたんチケット売買 Wavedash
# CAN Chum Card[キャンチャムカード]公式アプリ CAN COMPANY LTD.
# 「いいものアプリ」毎日旬のおトク情報をお届け！ Dinos Cecile Co.Ltd.
# SHEL'TTER PASS （シェルターパス） Baroque Japan
# メルカリ カウル - 本・CD・DVD・ゲーム専用フリマアプリ Mercari
# 郵便局のネットショップ Japan Post
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-27-7fedbec4b3d5> in <module>()
#      23 password = 'Jamie8449671' # 你的密码
#      24 rank_url  ='https://www.appannie.com/apps/google-play/top-chart/?country=JP&category=30&device=&date=2018-11-30&feed=All&rank_sorting_type=rank&page_number=0&page_size=100&table_selections='
# ---> 25 appann(username,password,rank_url)
#      26 appann(username,password,rank_url)
#
# <ipython-input-27-7fedbec4b3d5> in appann(username, password, rank_url)
#      15         content =driver.find_elements_by_css_selector('tr.main-row.table-row')
#      16         for i in content:
# ---> 17             name = i.find_element_by_css_selector('.app-link').text
#      18             company_name = i.find_element_by_css_selector('.company-link').text.replace(',','')
#      19             print(name,company_name)
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_css_selector(self, css_selector)
#     428             element = element.find_element_by_css_selector('#foo')
#     429         """
# --> 430         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     431
#     432     def find_elements_by_css_selector(self, css_selector):
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".app-link"}
#   (Session info: chrome=66.0.3359.139)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.17134 x86_64)
