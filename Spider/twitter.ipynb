# %%
# %load twitter.py
url = 'https://mobile.twitter.com/NausGlobal/status/974481846070231040'


import tweepy
from tweepy import OAuthHandler

consumer_key = 'kDMX2rApBKm1D2kCy0NfeW4Ru'
consumer_secret = 'wrnmQvH90gB0Req3Q5lnm6ruNercTyFjeLHlb6sETfeCPKZX4N'
access_token = '3272682498-PcewubomkAKDoDyxQVhk5wCdKWqIaN8ykjOAaUI'
access_secret = 'F3unOH8LobxrhZOHL36DMOydwHtKDQs4ZFcvRN0SimfwN'


auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth,proxy='https://127.0.0.1:1080')

url='https://twitter.com/Devanggupta7'
username = url.split('/')[-1]
print(username)
user = api.get_user(username)

print(user.followers_count)
# Out:
# Devanggupta7
# 15

# %%
import tweepy
from tweepy import OAuthHandler
import csv

consumer_key = 'kDMX2rApBKm1D2kCy0NfeW4Ru'
consumer_secret = 'wrnmQvH90gB0Req3Q5lnm6ruNercTyFjeLHlb6sETfeCPKZX4N'
access_token = '3272682498-PcewubomkAKDoDyxQVhk5wCdKWqIaN8ykjOAaUI'
access_secret = 'F3unOH8LobxrhZOHL36DMOydwHtKDQs4ZFcvRN0SimfwN'


auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth,proxy='https://127.0.0.1:1080')


with open("Bounty Progress Twitter.csv",'r') as f:
    content = csv.reader(f)
    urls = [row[3] for row in content]
    for u in urls[1:]:
        try:
            username = u.split('/')[-1]
            user = api.get_user(username)
            print(username,user.followers_count)
        except Exception:
            print(username,'error')
            continue
# Out:
# cryptoinsanemc 6055
# btc0Reth 951
# airdropalive 1019
# LyudmAbr3 644
# vi_kov 3323
# Svetik5888 1730
# vi77ip 3970
# Irinatoken 2233
# Vitallliy100 4334
# lunkin2910 10308
# lunkins1909 10447
# quas1986 5415
# aoleng27685445 1513
# V606458451 936
# Avizzarr 6000
# Zainul10411162 2170
# dron88091 3984
# CrazyClock105 2318
# PinkFoxic 2262
# mitinvla 5575
# makkosh_tm 61
# Kissnoone 3504
# idol_fes 12923
# idol_fes 12923
# harrygh20 1169
# SuwantaTata 1889
# AKPEKIAYEBAESIN 690
# 986855260248420352?s=20 error
# Yokopranimbo3 11070
# 974481846070231040 error
# DanataRober 779
# 974481846070231040 error
# adielsetiawan1 742
# cryptodiamond03 600
# crypto_ted 233
# njoku_chidima 784
# jamesndungu 354
# 974481846070231040 error
# ATertyichnyiy 11137
# MuhamadDikri_1 error
# YuriLapunov 4072
# quoting_lives 5490
# rpisini77 65
# Anggel74258155 3351
# Izenk10 3514
# DavanishFauzi 2598
# dndyrw 374
# annmon_a 1008
# Huym1992?s=07 error
# eugene_korn 6610
# Marianaled25 error
# ...

# %%
import tweepy
from tweepy import OAuthHandler
import csv

consumer_key = 'kDMX2rApBKm1D2kCy0NfeW4Ru'
consumer_secret = 'wrnmQvH90gB0Req3Q5lnm6ruNercTyFjeLHlb6sETfeCPKZX4N'
access_token = '3272682498-PcewubomkAKDoDyxQVhk5wCdKWqIaN8ykjOAaUI'
access_secret = 'F3unOH8LobxrhZOHL36DMOydwHtKDQs4ZFcvRN0SimfwN'


auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth,proxy='https://127.0.0.1:1080')


with open('Bounty Twitter follwer.csv','w',encoding='utf-8') as w:
    
    with open("Bounty Progress Twitter.csv",'r') as f:
        content = csv.reader(f)
        urls = [row[3] for row in content]
        for u in urls[1:]:
            try:
                username = u.split('/')[-1]
                user = api.get_user(username)
                followers = user.followers_count
                w.write('{},{},{}\n'.format(u,username,followers))
            except Exception:
                w.write('{},{},{}\n'.format(u,username,'url error'))        
                continue
            
print('The END')
# Out:
# The END

# %%
import csv
with open("Bounty Progress Twitter.csv",'r') as f:
    content = csv.reader(f)
    rows = [row[3] for row in content]
print(rows[1:])
# Out:
# ['https://twitter.com/cryptoinsanemc', 'https://twitter.com/btc0Reth', 'https://twitter.com/airdropalive', 'https://twitter.com/LyudmAbr3', 'https://twitter.com/vi_kov', 'https://twitter.com/Svetik5888', 'https://twitter.com/vi77ip', 'https://twitter.com/Irinatoken', 'https://twitter.com/Vitallliy100', 'https://twitter.com/lunkin2910', 'https://twitter.com/lunkins1909', 'https://twitter.com/quas1986', 'https://mobile.twitter.com/aoleng27685445', 'https://twitter.com/V606458451', 'https://twitter.com/Avizzarr', 'https://mobile.twitter.com/Zainul10411162', 'https://twitter.com/dron88091', 'https://twitter.com/CrazyClock105', 'https://twitter.com/PinkFoxic', 'https://twitter.com/mitinvla', 'https://twitter.com/makkosh_tm', 'https://twitter.com/Kissnoone', 'https://twitter.com/idol_fes', 'https://twitter.com/idol_fes', 'https://www.twitter.com/harrygh20', 'https://www.twitter.com/SuwantaTata', 'https://twitter.com/AKPEKIAYEBAESIN', 'https://twitter.com/Devanggupta7/status/986855260248420
# ...

# %%
import re
text = '@Nam19836887 3月18日 更多 回复 @NausGlobal Telegram username: thaiha2302 0x2caE037c22cb522DA9C592e996DEE9CB37225a8c'
split_text = text.split()
print(split_text)
address = r'(0x[a-z0-9A-Z]{40})'
name = r'(@[a-z0-9A-Z_]+)'
date = r'(\d{1,2}月\d{1,2}日)'
for st in split_text:
    if re.search(address,st):
        print(re.search(address,st).group(0))
    if re.search(date,st):
        print(re.search(date,st).group(0))
    if re.search(name,st):
        if re.search(name,st).group(0) != '@NausGlobal':
            print(re.search(name,st).group(0))
# Out:
# ['@Nam19836887', '3月18日', '更多', '回复', '@NausGlobal', 'Telegram', 'username:', 'thaiha2302', '0x2caE037c22cb522DA9C592e996DEE9CB37225a8c']
# @Nam19836887
# 3月18日
# 0x2caE037c22cb522DA9C592e996DEE9CB37225a8c

# %%
import re
text = '''Nam‏ @Nam19836887 3月18日更多回复 @NausGlobalTelegram username: thaiha23020x2caE037c22cb522DA9C592e996DEE9CB37225a8c@thuyha2003 @kingcxh89 @trantunhi26111回复 0 转推 1 喜欢回复  1   转推    喜欢  1NAUS‏ @NausGlobal 3月20日更多hahahaha~Thai Ha. I find you in NAUS GROUP0回复 0 转推 0 喜欢回复    转推    喜
amNguyen‏ @trangtretrau97 3月16日更多回复 @NausGlobal0xe21d758aa662d13Df765BD1D02ecE7d4CB7d63dD0回复 0 转推 0 喜欢回复    转推    喜欢  BitconnectX‏ @BitconnectXnews 3月16日更多回复 @NausGlobal@takat20 @suat2541 @selim3020x78cC122dFcD9059EA2899912fB338a7D1590fcbD0回复 0 转推 0 喜欢回复    转推    喜欢  Amir khan‏ @shaf_amir 3月16日更多回复 @NausGlobal0x54D8865302846272be3464d532DFF62A357538b40回复 0 转推 0 喜欢回复    转推    喜欢  harpreet singh‏ @harpreet_s87 3月16日更多回复 @NausGlobal0x480815747638e12A152D888eCaCD8C25bfe59B310回复 0 转推 0 喜欢回复    转推    喜欢  Levorg‏ @Levorg_Z 3月16日更多回复 @NausGlobal0xDfa0831222A0E9cAC42B7eDaC6b43Ff5664F8bF70回复 0 转推 0 喜欢回复    转推    喜欢  パーマン45‏ @6dGyhBCkMZwgbro 3月16日更多回复 @NausGlobal0x6403F572b1679C25E47C338c5E08491FF04aB25A0回复 0 转推 0 喜欢回复    转推    喜欢  Viczzytech-Crypto‏ @viczzytech 3月16日更多回复 @NausGlobal0x3Ee75dd288242aCC1A6fEE705e7d46A970235A0D0回复 0 转推 0 喜欢回复    转推    喜欢  dave burge‏ @truesaints 3月16日更多回复 @NausGlobal@YOPABRICEC @hamoLapik@ycleptShawn 0x2448Dde4D09F8AD1d017385aDD46D15A4d5b489c0回复 0 转推 0 喜欢回复    转推    喜欢  YOPA KWIBOU‏ @kwibou 3月16日更多回复 @NausGlobal@KingJames@AiSaifu @leyopu 0x316dd3e8f095b2914e88ed6d5e24b785c9eeb41b0回复 0 转推 0 喜欢回复    转推    喜欢  YOPA BRICE‏ @leyopu 3月16日更多回复 @NausGlobal0x29978D0652c77F9cD170E866B0BDaa086B60ac850回复 0 转推 0 喜欢回复    转推    喜欢  David Nwokoma Jnr‏ @dejuniordave 3月16日更多回复 @NausGlobal0x1245ed611710C2dfeD46b09e82FD616aCCed546D0回复 0 转推 0 喜欢回复    转推    喜欢  '''

address = r'(0x[a-z0-9A-Z]{40})'
name = r'(@[a-z0-9A-Z_]+)'
date = r'(\d{1,2}月\d{1,2}日)'
reg = r'(?<=@).+?(?=更多)'
infos = re.findall(reg,text)
eths = re.findall(address,text)
print(len(infos))
print(len(eths))


#for i in range(len(eth)):
#        print(infos[i]+eths[i])
# Out:
# 138
# 126

# %%
a='0xAC1013E95c478b07e291D5879c93123df3B253d1'
n = 0
for i in a:
    n += 1
print(n)
# Out:
# 42

# %%
import re
content = '''
@Nam19836887 3月18日 更多
回复 @NausGlobal
Telegram username: thaiha2302
0x2caE037c22cb522DA9C592e996DEE9CB37225a8c

@thuyha2003 @kingcxh89 @trantunhi2611
1回复 0 转推 1 喜欢
回复  1   转推    喜欢  1

@harpreet_s87 3月16日 更多
回复 @NausGlobal
0x480815747638e12A152D888eCaCD8C25bfe59B31
0回复 0 转推 0 喜欢
回复    转推    喜欢  

'''
address = r'(0x[a-z0-9A-Z]{40})'
name = r'(@[a-z0-9A-Z_]+)'
date = r'(\d{1,2}月\d{1,2}日)'
reg = r'(?<=@).+?(?=更多)'
infos = re.findall(reg,content)
eths = re.findall(address,content)
for i in range(len(infos)):
    print(infos[i]+eths[i])
# Out:
# Nam19836887 3月18日 0x2caE037c22cb522DA9C592e996DEE9CB37225a8c
# harpreet_s87 3月16日 0x480815747638e12A152D888eCaCD8C25bfe59B31

# %%
#encoding=utf8
import requests
from bs4 import BeautifulSoup
from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

url = 'https://twitter.com/NausGlobal/status/974481846070231040'
userurl = 'https://twitter.com/Nam19836887/status/975176538910965760'

proxie = {
    'http':'http://127.0.0.1:1080',
    'https':'https://127.0.0.1:1080'}

header = { 
    'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
    }

data = requests.get(url,headers = header,verify=False,proxies = proxie)

soup = BeautifulSoup(data.text,'html.parser')

# %%
from selenium import webdriver
import time
import re
from requests_html import HTMLSession
session = HTMLSession()
proxie = {'https':'https://127.0.0.1:1080'}

url = 'https://twitter.com/NausGlobal/status/974481846070231040'

options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
driver = webdriver.Chrome(chrome_options=options)

driver.get(url)


tweet = driver.find_elements_by_css_selector('.js-tweet-text-container')
time = driver.find_elements_by_css_selector('._timestamp')
fullname = driver.find_elements_by_css_selector('.FullNameGroup')

print(len(tweet))
print(len(time))
print(len(fullname))
for t in tweet:
    print(t.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-44-1b52887b402e> in <module>()
#      22
#      23 for i in content:
# ---> 24     print(i.find_element_by_css_selector('.js-tweet-text-container'))
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_css_selector(self, css_selector)
#     428             element = element.find_element_by_css_selector('#foo')
#     429         """
# --> 430         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     431
#     432     def find_elements_by_css_selector(self, css_selector):
#
# c:\users\win7\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# ...

# %%
from selenium import webdriver
import time
import re
from requests_html import HTMLSession
session = HTMLSession()
proxie = {'https':'https://127.0.0.1:1080'}

url = 'https://twitter.com/NausGlobal/status/974481846070231040'

options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
driver = webdriver.Chrome(chrome_options=options)

driver.get(url)

time.sleep(1)

target = driver.find_element_by_xpath('//*[@id="permalink-overlay-dialog"]/div[3]/div/div/div[4]/div')

for i in range(10):
    driver.execute_script('arguments[0].scrollIntoView();',target)
    time.sleep(1)

driver.implicitly_wait(10)

tweet = driver.find_elements_by_css_selector('.TweetTextSize')
time = driver.find_elements_by_css_selector('.time')
fullname = driver.find_elements_by_css_selector('.FullNameGroup')

driver.implicitly_wait(10)



address = r'(0x[a-z0-9A-Z]{40})'


with open('twitter20180503.csv','w',encoding='utf-8') as f:
    for i in range(len(tweet)):
        if re.search(address,tweet[i].text):
            eth = re.search(address,tweet[i].text).group(0)
            date = time[i].text
            name = fullname[i].text
            f.write('{},{},{}\n'.format(name,date,eth))

print('The END')            
            
driver.implicitly_wait(10)    
    
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time


url = 'https://twitter.com/NausGlobal/status/974481846070231040'

options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
driver = webdriver.Chrome(chrome_options=options)

driver.get(url)


target = driver.find_element_by_xpath('//*[@id="permalink-overlay-dialog"]/div[3]/div/div/div[4]/div')

for i in range(10):
    driver.execute_script('arguments[0].scrollIntoView();',target)
    time.sleep(1)




driver.quit()

# %%
from selenium import webdriver
import time
import re
from requests_html import HTMLSession
session = HTMLSession()
proxie = {'https':'https://127.0.0.1:1080'}

url = 'https://twitter.com/NausGlobal/status/974481846070231040'

options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
driver = webdriver.Chrome(chrome_options=options)

driver.get(url)

time.sleep(1)

target = driver.find_element_by_xpath('//*[@id="permalink-overlay-dialog"]/div[3]/div/div/div[4]/div')

for i in range(10):
    driver.execute_script('arguments[0].scrollIntoView();',target)
    time.sleep(1)

driver.implicitly_wait(10)

tweet = driver.find_elements_by_css_selector('.js-tweet-text-container')
time = driver.find_elements_by_css_selector('._timestamp')
fullname = driver.find_elements_by_css_selector('.FullNameGroup')

driver.implicitly_wait(10)


address = r'(0x[a-z0-9A-Z]{40})'


with open('twitter20180503.csv','w',encoding='utf-8') as f:
    for i in range(len(tweet)):
        if re.search(address,tweet[i].text):
            eth = re.search(address,tweet[i].text).group(0)
            date = time[i].text
            name = fullname[i].text
            f.write('{},{},{}\n'.format(name.strip(),date.strip(),eth.strip()))

print('The END')              
    
driver.quit()
# Out:
# The END

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import csv


url = 'https://twren.ch/'
tweet = 'https://twitter.com/NausGlobal/status/974481846070231040'

driver = webdriver.Chrome()

driver.get(url)
driver.find_element_by_id('tweet_input').clear()
driver.find_element_by_id('tweet_input').send_keys(tweet)

driver.find_element_by_id('load_btn').click()

time.sleep(10)


retweets = driver.find_elements_by_css_selector('tbody a')
name = [i.text for i in retweets]


time.sleep(10)


with open('TwitterConfirmation0523.csv','w',encoding='utf-8') as w:
    with open("NAUS Twitter0523.csv",'r',encoding='utf-8') as f:
        content = csv.reader(f)
        urls = [row[3] for row in content]
        for u in urls[1:]:
            
            username = u.split('/')[-1]
            if username in name:
                w.write('{},{}\n'.format(username,'retweet confirmation'))
            else:
                w.write('{},{}\n'.format(username,'retweet deny'))
                
print('The END')                   
driver.close()
# Out:
# The END

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import csv


url = 'https://twren.ch/'
tweet = 'https://twitter.com/NausGlobal/status/974481846070231040'

driver = webdriver.Chrome()

driver.get(url)
driver.find_element_by_id('tweet_input').clear()
driver.find_element_by_id('tweet_input').send_keys(tweet)

driver.find_element_by_id('load_btn').click()

time.sleep(10)


retweets = driver.find_elements_by_css_selector('tbody a')
name = [i.text for i in retweets]


time.sleep(10)



with open("NAUSTwitterProgress0505.csv",'r',encoding='utf-8') as f:
    content = csv.reader(f)
    urls = [row[3] for row in content]
    for u in urls[1:]:  
        username = u.split('/')[-1]
        if username in name:
            print(u,username,'retweet confirmation')
        else:
            print(u,username,'retweet deny')

time.sleep(10)                
print('The END')     



              
driver.close()
# Out:
# https://twitter.com/cryptoinsanemc cryptoinsanemc retweet deny
# https://twitter.com/btc0Reth btc0Reth retweet confirmation
# https://twitter.com/airdropalive airdropalive retweet confirmation
# https://twitter.com/LyudmAbr3 LyudmAbr3 retweet confirmation
# https://twitter.com/vi_kov vi_kov retweet confirmation
# https://twitter.com/Svetik5888 Svetik5888 retweet confirmation
# https://twitter.com/vi77ip vi77ip retweet confirmation
# https://twitter.com/Irinatoken Irinatoken retweet confirmation
# https://twitter.com/Vitallliy100 Vitallliy100 retweet confirmation
# https://twitter.com/lunkin2910 lunkin2910 retweet confirmation
# https://twitter.com/lunkins1909 lunkins1909 retweet confirmation
# https://twitter.com/quas1986 quas1986 retweet confirmation
# https://mobile.twitter.com/aoleng27685445 aoleng27685445 retweet confirmation
# https://twitter.com/V606458451 V606458451 retweet confirmation
# https://twitter.com/Avizzarr Avizzarr retweet confirmation
# ...

# %%
import tweepy
from tweepy import OAuthHandler
import time

consumer_key = 'kDMX2rApBKm1D2kCy0NfeW4Ru'
consumer_secret = 'wrnmQvH90gB0Req3Q5lnm6ruNercTyFjeLHlb6sETfeCPKZX4N'
access_token = '3272682498-PcewubomkAKDoDyxQVhk5wCdKWqIaN8ykjOAaUI'
access_secret = 'F3unOH8LobxrhZOHL36DMOydwHtKDQs4ZFcvRN0SimfwN'


auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth,proxy='https://127.0.0.1:1080')
num = 0
for user in tweepy.Cursor(api.followers,screen_name = 'NausGlobal',count =200 ).items():
    print(user.screen_name)
    num += 1

print(num)
# Out:
# FinnoHayanal
# rIsnamjah
# Lazuardiyanto
# rezpect_jember
# Ngovantoan20
# di2kashter
# Ruma94234898
# rofik280290
# oschi3
# dutta_pra
# arip3anggoro
# sefhunc
# HashiniRathnay4
# treatme94193874
# ryan_fadheel
# m_bukhor
# chelsia_98
# Amri831
# LeinujZ
# ardctss
# CryptoKing1913
# MeilTweet
# weirensuperb
# rahmalvirana
# sherlyhoy
# karinaafanah
# ilyasbeller
# vatahbokek
# ivanjontea
# harissengke
# hajikulproy
# andricoinhunter
# xaojunt
# Bojessubejo
# manzvenz07
# crypto5002
# Fektur77
# harm4ul
# onur_ogurlu
# Dzmitry22
# niks13773
# Icutmaniz1
# erfanmaulida
# ssaidarahman2
# zininaks
# kathymith15101
# aAYfu2QkFON0W1b
# Dinom53692043
# nguyenhuy1107
# habibur9606
# anuskasarma4
# sonath2611
# Tuan77322208
# farjana1155
# HaiNguy72755203
# nilbtc4556
# Indriasari277
# IrawatiSalma
# MaysaraAnzar
# Thony4741
# DevanNaratama
# andy_flotado
# cryptbest
# BergFiles
# asemene41
# dimagunner23
# doannguyen8
# MoonShadovv
# rubykoroza
# sugionowibowo71
# syrulhawkers
# ...
