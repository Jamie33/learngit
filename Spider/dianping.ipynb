# %% [markdown]
# ## 大众点评
#
# 操作
#
# - `cd C:\Program Files (x86)\Google\Chrome\Application`
#
# - `chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\selenium\AutomationProfile"`
#
# https://www.dianping.com/shop/kaiOj6rNZxW6HVO1?utm_source=poiopen&utm_medium=8701991&utm=8701991&utm_campaign=mshxq#dianping
#
# ### 第一次尝试

# %%
from selenium import webdriver
import time,requests
import datetime,requests
import json
from bs4 import BeautifulSoup
from seleniumrequests import Chrome
from urllib.parse import urlencode

class DianPing():
    
    def __init__(self,url,target_url,save_file):
        self.target_url = target_url
        self.url = url
        self.save_file = save_file
        self.options = webdriver.ChromeOptions()
    
    def login(self):
        # r代表后面的字符串斜杠不转义，''表示python识别空格
        self.options.add_argument(r"user-data-dir=C:\Users\45207\AppData\Local\Google\Chrome\User''Data\Default\Login''Data")
        self.options.add_experimental_option('debuggerAddress','127.0.0.1:9222')
        self.driver = webdriver.Chrome(executable_path=r"C:\Users\45207\anaconda3\Scripts\chromedriver.exe",port=0,options=self.options)    
        print('进入目标地址')
        self.driver.get(url)
        print('等待20s 扫描登录')
        time.sleep(20)
        self.driver.get(target_url)
        print('等待20s 验证')
        time.sleep(10)
        html = self.driver.page_source
        print(html)

        
    # 解析物流内容
    def parse_html(content,save_file):
            html_json = html['data']['result']
            track_summary = driver.find_element_by_id('pre').text

            print()
    
    
#     order_status_list = content.split('\n')[:-2]
#     order_status_list_len = len(order_status_list)
#     with open(save_file, 'a', encoding='utf-8') as w:
#         for i in order_status_list:
#             tracking_info = i.split('\t')
#             tracking_num = tracking_info[0]
#             tracking_time = tracking_info[3].split(',')[0]
#             tracking_status = tracking_info[4]
#             try:
#                 tracking_during = tracking_info[5]
#             except IndexError:
#                 tracking_during = '无'
#             print('物流单号：{},更新时间：{},当前状态：{},：物流耗时{}'.format(tracking_num,tracking_time,tracking_status,tracking_during))
#             w.write('{},{},{},{}\n'.format(tracking_num,tracking_time,tracking_status,tracking_during))
#     print('写入 csv 文件')



    def close(self):
        self.driver.close()
                
url = 'https://www.dianping.com/'
target_url = 'http://www.dianping.com/shop/kaiOj6rNZxW6HVO1/review_all/p1'
save_file = r'dianping_hotel_reviews.csv'

    
if __name__ == '__main__':
    dianping = DianPing(target_url,save_file)
    dianping.login()
#     dianping.json_post()
#     print('Done')
# Out:
# 进入目标地址
# 等待20s 扫描登录
# <html lang="en"><head>
#         <meta charset="UTF-8">
#         <meta name="sogou_site_verification" content="qxQgbwO3cZ">
#         <meta name="shenma-site-verification" content="688cc4e286b23880eb0eaec7476aecbe_1492066611">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>北京美食_生活_团购_旅游_电影_优惠券 - 大众点评网</title>
#         <script src="https://hm.baidu.com/hm.js?602b80cf8079ae6591966cc70a3940e7"></script><script>
#             var _start = +new Date();
#         </script>
#         <meta name="keyword" content="北京点评, 北京团购, 北京美食, 北京优惠券, 北京生活服务,  北京餐厅,  北京电影票">
#         <meta name="description" content="推荐 北京吃喝玩乐优惠信息，提供美食餐厅、酒店旅游、电影票、家居装修、美容美发、运动健身等各类生活服务，通过海量真实消费评论的聚合，帮您选到满意商家。">
#         <!--网页标题左侧显示-->
#         <link rel="icon" type="image/x-icon" href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico">
#         <!--收藏夹显示图标-->
#         <link rel="shortcut icon" type="image/x-icon" href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico">
#         <link rel="stylesheet" type="text/css" href="//www.dpfile.com/app/pc-common/index.min.a77ed6b2d125089a497ce8978cecc46b.css">
#         <!-- 注入页头需要的参数  -->
#         <script type="text/javascript">
#             window._DP_HeaderData = {
#                 'cityId': '2',  // 城市id , 必须，默认: '1'
#                 'cityCName': '北京', // 城市中文名, 必须, 默认:上海
#                 'cityEnName': 'beijing', // 城市英文名，默认：shanghai
#                 'pageType': 'index', // 页面类型，枚举类型 'index' || 'search', 必须， 默认：'index'
#                     'userId': '118127639',   // 用户id， 若用户已经登录，必须传，未登录时，可不传此参数，或者传空字符串''，默认:'', 未登录状态
#                     'userName':'JAM_IE',   // 用户名， 若用户已经登录，必须传，未登录时，可不传此参数，或者传空字符串''，默认:'', 未登录状态
#                 'ipCityCName': '', // ip定位城市中文名
#                 'ipCityEName': '', // ip定位城市英文名
#                 'seo': 'false', // seo流量标示
#             }
#         </script>
#         <!--灵犀web4.0打点配置-->
#         <meta name="lx:category" content="dianping_nova">
#         <meta name="lx:appnm" content="dp_pc">
#         <meta name="lx:autopv" content="off">
#         <!-- 配置 DNS 预解析 -->
#         <link rel="dns-prefetch" href="//analytics.meituan.net">
#         <script type="text/javascript">
#             !(function (win, doc, ns) {
#                 var cacheFunName = '_MeiTuanALogObject';
#                 win[cacheFunName] = ns;
#                 if (!win[ns]) {
#                     var _LX = function () {
#                         _LX.q.push(arguments);
#                         return _LX;
#                     };
#                     _LX.q = _LX.q || [];
#                     _LX.l = +new Date();
#                     win[ns] = _LX;
#                 }
#             })(window, document, 'LXAnalytics');
#
#             ;(function(){
#                 var environment = null; // 设置环境信息
#                 /**
#                  * 设置业务变量说明 valLab
#                  * 自定义业务扩展变量名称: user_id -> 用户id
#                  * 自定义业务扩展变量名称: city_id -> 城市
#                  */
#                 var valLab = {
#                     "city_id": window._DP_HeaderData.cityId,
#                     "user_id": window._DP_HeaderData.userId
#                 };
#                 var cid = 'c_ywm5nx3j' // xxx为具体的cid编号，
#                 LXAnalytics('pageView',valLab, environment, cid);
#             })();
#         </script>
#         <script src="//analytics.meituan.net/analytics.js" type="text/javascript" charset="utf-8" async="" defer=""></script>
#         <script type="text/javascript">
#             "use strict";!function(){var a=arguments.length>0&&void 0!==arguments[0]?arguments[0]:"_Owl_",i=window,t={page:!0,resource:!0,js:!0};i[a]||(i[a]={isRunning:!1,isReady:!1,preTasks:[],config:t,dataSet:[],use:function(a,t){this.isReady&&i.Owl&&i.Owl[a](t),this.preTasks.push({api:a,data:[t]})},add:function(a){this.dataSet.push(a)},run:function(a){var t=this;if(!this.isRunning){this.isRunning=!0;var e=a||this.config;if(!1!==e.js){var n=i.onerror;i.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),n&&n.apply(i,arguments)}.bind(this)}var r=i.addEventListener||i.attachEvent;!1!==e.page&&r("load",function(){if(!t.isReady){var a=i.performance&&i.performance.timing;t.add({type:"pageTime",data:[a]})}}),!1!==e.resource&&(r("error",function(a){t.isReady||t.add({type:"resError",data:[a]})},!0),r("load",function(a){t.isReady||t.add({type:"resTime",data:[a]})}))}}})}();
#             //默认配置启动全部监控，业务可根据需要手动关闭其中任一种类的监控,_Owl_为全局变量
#             _Owl_.run({
#                 page: true, //页面性能采集
#                 js: true, //JS全局错误采集
#                 resource: true //资源加载错误、性能采集
#             })
#         </script>
#         <script type="text/javascript">
#             if (window.location.search.indexOf("__mock_kodo=1") != -1) {
#                 var pre = "http://preview.www.dpfile.com";
#                 if (window.location.protocol == "https:") {
#                     pre = "https://www.dpfile.com";
#                 }
#                 document.write("<script src='" + pre + "/app/dp-parrot-mocker/parrot.js' type='text/javascript' charset='utf-8'><\/script>");
#             }
#         </script>
#         <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.5.16.js"></script>
#         <script>
#             var devMode = location.href.indexOf('.51ping.com') !== -1
#             Owl.start({
#                 devMode: devMode,
#                 project: 'pc-new',
#                 pageUrl: location.origin + location.pathname,
#                 page: {
#                     sample: devMode ? 1 : 0.1,
#                     auto: false
#                 }
#             })
#             //owl加载时间
#             Owl.addPoint({
#                 position: 0,
#                 duration: +new Date() - _start
#             })
#         </script>
# <link rel="stylesheet" href="//www.dpfile.com/app/dpindex-new-static/static/index.min.b3bc16c020f78efb88bed66163b8fd6a.css" type="text/css">    </head>
#     <body data-new-gr-c-s-check-loaded="14.1004.0" data-gr-ext-installed="" style="position: relative;">
#                 <div class="fullScreenFlash destroy">
#                     <div class="countDown">关闭</div>
#                     <div class="content">
#                         <div class="left">
#                             <div class="phoneVideo">
#                                 <video loop="loop" preload="auto" autoplay="true" muted="muted" class="fullScreenVideo" id="fullScreenVideo" src="//1251413404.vod2.myqcloud.com/vodgzp1251413404/5285890800710309870/m0cET0REBZsA.mp4"></video>
#                             </div>
#                             <div class="phoneShell"></div>
#                         </div>
#                         <div class="right">
#                             <div class="dpLogo"></div>
#                             <div class="dpText">发现品质生活</div>
#                             <div class="dpQrcode">
#                                 <div class="qrcodeItem">
#                                     <div class="qrcode4ios"></div>
#                                     <div class="qrcodeText">IOS版下载</div>
#                                 </div>
#                                 <div class="qrcodeItem">
#                                     <div class="qrcode4android"></div>
#                                     <div class="qrcodeText">Android版下载</div>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#         <div id="index-main">
#             <!--页头部分-->
#             <div class="header-container" id="header-container">
#             <div id="top-nav" class="top-nav"> <div class="top-nav-container clearfix"> <div class="group J-city-select"> <!--城市选择--> <a target="_blank" class="city J-city"><span class="map-icon"></span><span class="J-current-city">北京</span><span class="J-city-change">[更换]</span></a> <div class="city-list J-city-list Hide"> <div class="group clearfix"> <h3 class="title">国内城市</h3> <div> <a href="//www.dianping.com/shanghai" class="city-item">上海</a> <a href="//www.dianping.com/beijing" class="city-item current-city">北京</a> <a href="//www.dianping.com/guangzhou" class="city-item">广州</a> <a href="//www.dianping.com/shenzhen" class="city-item">深圳</a> <a href="//www.dianping.com/tianjin" class="city-item">天津</a> <a href="//www.dianping.com/hangzhou" class="city-item">杭州</a> <a href="//www.dianping.com/nanjing" class="city-item">南京</a> <a href="//www.dianping.com/suzhou" class="city-item">苏州</a> <a href="//www.dianping.com/chengdu" class="city-item">成都</a> <a href="//www.dianping.com/wuhan" class="city-item">武汉</a> <a href="//www.dianping.com/chongqing" class="city-item">重庆</a> <a href="//www.dianping.com/xian" class="city-item">西安</a> </div> </div> <div class="group clearfix"> <h3 class="title">国外城市</h3> <div> <a href="//www.dianping.com/tokyo" class="city-item">东京</a> <a href="//www.dianping.com/seoul" class="city-item">首尔</a> <a href="//www.dianping.com/bangkok" class="city-item">曼谷</a> <a href="//www.dianping.com/paris" class="city-item">巴黎</a> </div> </div> <a class="all" href="//www.dianping.com/citylist">更多城市 &gt;</a> </div> </div> <div class="group quick-menu "> <span class="userinfo-container"><a target="_blank" href="https://www.dianping.com/member/118127639" class="item left-split username J-user-trigger">JAM_IE</a>
#                             <span class="seprate">|</span>
#                        <a target="_blank" href="https://www.dianping.com/msg/notice" class="item left-split user-msg J-message-trigger">消息</a></span> <span class="seprate">|</span> <a rel="nofollow" href="https://www.dianping.com/member/myinfo" class="item J-my-center-trigger">个人中心<i class="icon i-arrow"></i></a> <span class="seprate">|</span> <a target="_blank" class="item J-shop-serve-trigger">商户服务<i class="icon i-arrow"></i></a> <span class="seprate">|</span> <a target="_blank" class="item J-help-trigger">帮助中心<i class="icon i-arrow"></i></a> </div> <div class="panel my-center J-my-center-target Hide"> <a href="https://www.dianping.com/member/118127639/reviews" data-click-name="reviews" target="_blank">我的评价</a><a href="https://www.dianping.com/member/118127639/wishlists" data-click-name="wishlists" target="_blank">我的收藏</a><a href="https://t.dianping.com/account/coupons" data-click-name="coupons" target="_blank">我的团购</a><a href="https://www.dianping.com/reservation/main/reserveDetailAction?type=userid&amp;key=1" data-click-name="booking" target="_blank">我的订座</a><a href="https://www.dianping.com/member/myinfo/setup/basic" data-click-name="setting" target="_blank">我的设置</a><a href="https://www.dianping.com/hotel/orders/list" data-click-name="hotel-order" target="_blank">酒店订单</a></div> <div class="panel my-center J-shop-serve-target Hide"> <a rel="nofollow" target="_blank" href="https://e.dianping.com/" data-click-name="shop-center">商户中心</a> <a rel="nofollow" target="_blank" href="https://e.dianping.com/claimcpc/page/index?source=dp" data-click-name="shop-coop">商户合作</a> <a rel="nofollow" target="_blank" href="https://daili.meituan.com/?comeFrom=dpwebMenu" data-click-name="daili">招募餐饮代理</a> <a rel="nofollow" target="_blank" href="https://daili.meituan.com/dz-zhaoshang" data-click-name="apollo">招募非餐饮代理</a> <a rel="nofollow" target="_blank" href="http://b.meituan.com/canyin/PC">餐饮商户中心</a> </div> <div class="panel my-center J-help-target Hide"> <a rel="nofollow" target="_blank" href="https://rules-center.meituan.com?from=dianpingPC" data-click-name="useragreement">平台规则</a> <a rel="nofollow" target="_blank" href="http://kf.dianping.com" data-click-name="kf">联系客服</a> </div> <div class="panel user-card J-user-target Hide"><a class="avatar" href="https://www.dianping.com/member/118127639" target="_blank"><img src="https://img.meituan.net/relationwxpic/c4795f2727245b8131e52687e891a7b62431.jpg%40120w_120h_1e_1c_1l%7Cwatermark%3D0"></a><span class="logout-container"><a class="setting" href="https://www.dianping.com/member/myinfo/setup/basic" data-click-name="setting" target="_blank">个人设置</a><span class="line">|</span><a class="logout" href="https://account.dianping.com/logout" data-click-name="logout">退出</a></span><p><a class="name" href="https://www.dianping.com/member/118127639" data-click-name="userName" target="_blank">JAM_IE</a><a href="https://www.dianping.com/member/guides/index" target="_blank"><span class="user-rank-rst urr-rank30"></span></a></p><p class="info"><a class="item" href="https://www.dianping.com/member/118127639/reviews" data-click-name="reviews" target="_blank">评价 3</a><a class="item" href="https://www.dianping.com/member/118127639/fans" data-click-name="fans" target="_blank">粉丝 7</a></p></div></div> </div> <div id="logo-input" class="logo-input single-logo-input "> <div class="logo-input-container clearfix"> <a title="大众点评网" href="/" class="logo"></a> <div class="search-box"> <div class="search-bar "> <span class="search-container clearfix"> <i class="i-search"></i> <span> <input id="J-search-input" class="J-search-input" x-webkit-speech="" x-webkit-grammar="builtin:translate" data-s-pattern="https://www.dianping.com/search/keyword/{0}/{1}_" data-s-epattern="https://www.dianping.com/beijing/{0}" data-s-cateid="0" data-s-cityid="1" type="text" placeholder="搜索商户名、地址、菜名、外卖等" autocomplete="off"> </span> <span class="search-bnt-panel"> <a target="_blank" class="search-btn J-search-btn" id="J-all-btn" data-s-chanid="0">搜索< ...
#             </div>
#             <!--首页主要的分类信息及用户信息-->
#             <div id="main-index" class="main-index">
#                 <!--图片轮播-->
# <!--图片轮播-->
# <div id="pic-nav" class="pic-nav jPicture-container" data-cacheindex="0">
#
#     <ul id="pic-nav-ul" class="pic-nav-ul jPicture-inner jPicture-slide nav-right" style="width: 5390px; left: -868.625px;"><li class="pic-item jPicture-part" id="pic-ad" data-midas="ad_cj%3DrhssCo8FjDpHdFNgAF96BSehbzhW6VaZueRUTWQ0-LPpvzj3wSxYI4gNy3UnjD1_LvLILdkTzEJgnQRVIvk4XL9n54TVnBYkpjKxnLHnXDMLpa2WmeiqzFK1XLIZgSTMohaKvguD7nPDkM94RwOqnRWZn_W-nz_zyI498PZ_QYXj6PJQuUiR7GpwwIP6ACBCQuDP93IuMKIjZfR4djPErCSx0QHtCi_z2JPeyHnFVtZyB-PWdyDb6lH3kv8a2SdtEn8tSvxw71Ur17J020ghIDhrOcPaF7h3HCFlUFHp6H3mWCxamUU2NgrM1tyPKr-bw_IOH0hshV4__SOnPkEe4_1pnYaDKLwxtKnUHYmXu5Tz1p162NBfP0G1laolR7UmENUcqU-8xOBCtLM61ZJ24vM97qwd7gcPXuaQpv8R3IDPBbVvcZorRn8yVRLJpRQXDpR-yQs%26sver%3D2%26ad_v%3D1%26ad_ci%3DrhssCo8XUIYXZAwMg1xqGaa-hMEumqoYAKAzg9uniEYpbltlwMEA242LsGlNWkH96Sm3Q3wpH1ZLztqJDGJZ-vq8dnBEybJamefFiA%26gwidx%3D5%26gwhost%3D14.yp" data-clickurl="" data-impressionurl="" data-viewed="true" data-click-inited="true" data-midas-tag="
# <!--热门分类商区地铁-->
# <div id="cata-hot" class="cata-hot cata-hot-double-">
#     <div class="cata-hot-detail cata-hot-info" data-click-name="全部" data-click-title="热门分类">
#         <div class="hot-title"><a href="//www.dianping.com/shopall/2/0" target="_blank" class="hot-title-link" data-click-name="热门分类标题" data-click-title="标题">热门分类</a></div>
#         <ul class="cata-hot-detail-item">
#             <li class="hot-item hot-item-0"><a href="//www.dianping.com/beijing/ch10/g1338" target="_blank" data-click-title="类目" data-click-name="私房菜">私房菜</a></li>
#             <li class="hot-item hot-item-1"><a href="//www.dianping.com/beijing/ch10/g2714" target="_blank" data-click-title="类目" data-click-name="水果生鲜">水果生鲜</a></li>
#             <li class="hot-item hot-item-2"><a href="//www.dianping.com/beijing/ch10/g33759" target="_blank" data-click-title="类目" data-click-name="食品保健">食品保健</a></li>
#             <li class="hot-item hot-item-3"><a href="//www.dianping.com/beijing/ch10/g34055" target="_blank" data-click-title="类目" data-click-name="早茶">早茶</a></li>
#             <li class="hot-item hot-item-4"><a href="//www.dianping.com/beijing/ch10/g34236" target="_blank" data-click-title="类目" data-click-name="饮品店">饮品店</a></li>
#             <li class="hot-item hot-item-5"><a href="//www.dianping.com/beijing/ch10/g34284" target="_blank" data-click-title="类目" data-click-name="特色菜">特色菜</a></li>
#             <li class="hot-item hot-item-6"><a href="//www.dianping.com/beijing/ch10/g34303" target="_blank" data-click-title="类目" data-click-name="烤肉">烤肉</a></li>
#             <li class="hot-item hot-item-7"><a href="//www.dianping.com/beijing/ch10/g311" target="_blank" data-click-title="类目" data-click-name="北京菜">北京菜</a></li>
#             <li class="hot-item hot-item-8"><a href="//www.dianping.com/beijing/ch10/g1783" target="_blank" data-click-title="类目" data-click-name="家常菜">家常菜</a></li>
#         </ul>
#     </div>
#     <div class="cata-hot-detail cata-hot-area" data-click-name="全部" data-click-title="热门商圈">
#         <div class="hot-title"><a href="//www.dianping.com/shopall/2/0#BDBlock" target="_blank" class="hot-title-link" data-click-name="热门商圈标题" data-click-title="标题">热门商圈</a></div>
#         <ul class="cata-hot-detail-item">
#             <li class="hot-item hot-item-0"><a href="//www.dianping.com/beijing/ch0/r2580" target="_blank" data-click-title="类目" data-click-name="三里屯/工体">三里屯/工体</a></li>
#             <li class="hot-item hot-item-1"><a href="//www.dianping.com/beijing/ch0/r1471" target="_blank" data-click-title="类目" data-click-name="望京">望京</a></li>
#             <li class="hot-item hot-item-2"><a href="//www.dianping.com/beijing/ch0/r1481" target="_blank" data-click-title="类目" data-click-name="西单">西单</a></li>
#             <li class="hot-item hot-item-3"><a href="//www.dianping.com/beijing/ch0/r1489" target="_blank" data-click-title="类目" data-click-name="五道口">五道口</a></li>
#             <li class="hot-item hot-item-4"><a href="//www.dianping.com/beijing/ch0/r2578" target="_blank" data-click-title="类目" data-click-name="国贸/建外">国贸/建外</a></li>
#             <li class="hot-item hot-item-5"><a href="//www.dianping.com/beijing/ch0/r1488" target="_blank" data-click-title="类目" data-click-name="中关村">中关村</a></li>
#             <li class="hot-item hot-item-6"><a href="//www.dianping.com/beijing/ch0/r1475" target="_blank" data-click-title="类目" data-click-name="王府井/东单">王府井/东单</a></li>
#             <li class="hot-item hot-item-7"><a href="//www.dianping.com/beijing/ch0/r1504" target="_blank" data-click-title="类目" data-click-name="崇文门">崇文门</a></li>
#             <li class="hot-item hot-item-8"><a href="//www.dianping.com/beijing/ch0/r2579" target="_blank" data-click-title="类目" data-click-name="双井">双井</a></li>
#         </ul>
#     </div>
#     <div class="cata-hot-detail cata-hot-metro" data-click-name="全部" data-click-title="地铁线">
#         <div class="hot-title"><a href="//www.dianping.com/shopall/2/0#MetroBlock" target="_blank" class="hot-title-link" data-click-name="地铁线标题" data-click-title="标题">地铁线</a></div>
#         <ul class="cata-hot-detail-item">
#             <li class="hot-item hot-item-0"><a href="//www.dianping.com/beijing/ch0/r2507" target="_blank" data-click-title="类目" data-click-name="10号线">10号线</a></li>
#             <li class="hot-item hot-item-1"><a href="//www.dianping.com/beijing/ch0/r3057" target="_blank" data-click-title="类目" data-click-name="4号线">4号线</a></li>
#             <li class="hot-item hot-item-2"><a href="//www.dianping.com/beijing/ch0/r2181" target="_blank" data-click-title="类目" data-click-name="5号线">5号线</a></li>
#             <li class="hot-item hot-item-3"><a href="//www.dianping.com/beijing/ch0/r2179" target="_blank" data-click-title="类目" data-click-name="1号线">1号线</a></li>
#             <li class="hot-item hot-item-4"><a href="//www.dianping.com/beijing/ch0/r8095" target="_blank" data-click-title="类目" data-click-name="6号线">6号线</a></li>
#             <li class="hot-item hot-item-5"><a href="//www.dianping.com/beijing/ch0/r2180" target="_blank" data-click-title="类目" data-click-name="2号线">2号线</a></li>
#             <li class="hot-item hot-item-6"><a href="//www.dianping.com/beijing/ch0/r2182" target="_blank" data-click-title="类目" data-click-name="13号线">13号线</a></li>
#             <li class="hot-item hot-item-7"><a href="//www.dianping.com/beijing/ch0/r7643" target="_blank" data-click-title="类目" data-click-name="8号线">8号线</a></li>
#             <li class="hot-item hot-item-8"><a href="//www.dianping.com/beijing/ch0/r8687" target="_blank" data-click-title="类目" data-click-name="14号线东段">14号线东段</a></li>
#         </ul>
#     </div>
# </div>                <!--用户信息区域-->
#                 <div id="userinfo-vip" class="userinfo-vip">
# <!--用户信息区域-->
# <div id="userinfo" class="user-info-con">
#     <div class="userinfo">
#         <div class="user-pic">
#             <a class="user-link" href="/member/118127639" data-click-name="用户头像" target="_blank">
#                 <img src="https://img.meituan.net/relationwxpic/c4795f2727245b8131e52687e891a7b62431.jpg%40120w_120h_1e_1c_1l%7Cwatermark%3D0" alt="用户头像" class="user">
#             </a>
#         </div>
#         <div class="hello-user"><span class="hello">上午好,</span>
#                                         <a href="/member/118127639">
#                                             <span class="hi-name">JAM_IE</span>
#                                         </a><span class="user-level level-3"></span></div>
#         <div class="use-day"><span>您已使用大众点评</span><span class="days-count">2422</span><span>天</span></div>
#         <div class="user-opt">
#             <div class="user-opt-nologin" data-click-name="未登录" style="height: 0px;">
#                 <a href="//account.dianping.com/login" class="opt-btn login">登录</a>
#                 <a href="//account.dianping.com/reg" class="opt-btn regsiter">注册</a>
#             </div>
#             <div class="user-opt-login" data-click-name="登录">
#                 <a class="info-detail collect" href="/member/118127639/wishlists" target="_blank" data-click-name="收藏">
#                     <div class="info-desc">收藏</div>
#                     <div class="info-count">25</div>
#                 </a>
#                 <a class="info-detail coupon" href="//t.dianping.com/account/coupons" target="_blank" data-click-name="团购券">
#                     <div class="info-desc">团购券</div>
#                     <div class="info-count">0</div>
#                 </a>
#             </div>
#         </div>
#     </div>
# </div>
# <!--点评头条，没有头条则展示二维码&ndash;&gt;-->
# <div id="index-headline" class="index-headline">
#             <!-- 二维码 -->
#         <div class="qr-code">
#             <div class="qr-con">
#                 <img class="qr-img" src="//p0.meituan.net/mobilem/2e60ff2116c2ae119032e2687a02693c11264.png" alt="点评二维码">
#             </div>
#             <div class="qr-hui">
#                 <div class="qr-hui-desc desc-hui">专享优惠</div>
#                 <div class="qr-hui-desc desc-coupon">专享优惠</div>
#             </div>
#         </div>
#
# </div>                </div>
#                 <div id="cata-detail" class="cata-detail">
#                     <!-- 美食，休闲娱乐 -->
#                     <!-- cata-part-single -->
#                         <div id="cata-part-one" class="cata-part cata-part-one cata-part-double cata-poi">
#                             <!--美食-->
# <div id="cata-food-index" class="cata-index cata-food-index" data-category="food">
#     <div class="cata-title">
#         <div class="cata-index-pic title-pic-food"></div>
#         <div class="title-dec">美食</div>
#         <div class="cata-tag">
#                     <a href="//www.dianping.com/beijing/ch10/g112" target="_blank" data-category="food" data-click-name="小吃快餐">
#                         <span class="tag-item">小吃快餐</span>
#                     </a>
#                     <a href="//www.dianping.com/beijing/ch10/g1817" target="_blank" data-category="food" data-click-name="粉面馆">
#                         <span class="tag-item">粉面馆</span>
#                     </a>
#                     <a href="//www.dianping.com/beijing/ch10/g2714" target="_blank" data-category="food" data-click-name="水果生鲜">
#                         <span class="tag-item">水果生鲜</span>
#                     </a>
#         </div>
#         <a href="//www.dianping.com/beijing/ch10" target="_blank" class="view-more" data-category="food" data-click-title="全部按钮" data-click-name="全部">
#             <span class="more-desc">全部</span>
#             <span class="arrow-right"></span>
#         </a>
#     </div>
#     <div class="cata-con">
#             <div class="cata-shop-item">
#                 <div class="shop-item">
#                     <a href="//www.dianping.com/shop/H44aA0ygrKwNug5m" target="_blank" class="shop-img shop-item-pic" data-category="food" data-click-title="图片" data-click-name="商家图片1" data-shopid="H44aA0ygrKwNug5m">
#                             <img lazy-src="https://qcloud.dpfile.com/pc/DrQVG9Hy1Ivtrtm0k2lx1lJd9kRQUj0smYk0d5BjY-F3X53EEsnT4aGMGwdxc_QTkkCBOWO5rApRy3gE6VS0Vg.jpg" src="https://qcloud.dpfile.com/pc/DrQVG9Hy1Ivtrtm0k2lx1lJd9kRQUj0smYk0d5BjY-F3X53EEsnT4aGMGwdxc_QTkkCBOWO5rApRy3gE6VS0Vg.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop
src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop/k9Ly1HlLnYdzzDPm" target="_blank" class="shop-name" data-category="food" data-click-title="标题" data-click-name="商家名称5" data-shopid="k9Ly1HlLnYdzzDPm">
#                             <span class="name-desc">研磨时光咖啡厅</span>
#                         </a>
#                         <div class="star-info">
#                             <span class="star star-35"></span>
#                             <span class="comment">107条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">光明楼/龙潭湖</span>
#                                 <span class="maincate-name">咖啡厅</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥35/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="cata-shop-item">
#                 <div class="shop-item">
#                     <a href="//www.dianping.com/shop/k21yLIFDQ3pieJ8c" target="_blank" class="shop-img shop-item-pic" data-category="food" data-click-title="图片" data-click-name="商家图片6" data-shopid="k21yLIFDQ3pieJ8c">
#                             <img lazy-src="http://p0.meituan.net/merchant/2c9e59372e463dc6dff2e1d188ba593d2021070.png%40340w_192h_1e_1l%7Cwatermark%3D0" src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop/k21yLIFDQ3pieJ8c" target="_blank" class="shop-name" data-category="food" data-click-title="标题" data-click-name="商家名称6" data-shopid="k21yLIFDQ3pieJ8c">
#                             <span class="name-desc">青龙湖小院羊棒骨</span>
#                         </a>
#                         <div class="star-info">
#                             <span class="star star-40"></span>
#                             <span class="comment">24条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">青龙湖镇</span>
#                                 <span class="maincate-name">羊蝎子火锅</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥45/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#     </div>
# </div>
#                             <!--休闲娱乐-->
# <div id="cata-entertainment-index" class="cata-index  cata-entertainment-index" data-category="entertainment">
#     <div class="cata-title">
#         <div class="cata-index-pic title-pic-ktv"></div>
#         <div class="title-dec">休闲娱乐</div>
#         <div class="cata-tag">
#                     <a href="//www.dianping.com/beijing/ch30/g2636" target="_blank" data-category="entertainment" data-click-name="运动健身">
#                         <span class="tag-item">运动健身</span>
#                     </a>
#                     <a href="//www.dianping.com/beijing/ch30/g141" target="_blank" data-category="entertainment" data-click-name="按摩/足疗">
#                         <span class="tag-item">按摩/足疗</span>
#                     </a>
#                     <a href="//www.dianping.com/beijing/ch30/g34089" target="_blank" data-category="entertainment" data-click-name="团建拓展">
#                         <span class="tag-item">团建拓展</span>
#                     </a>
#         </div>
#         <a href="//www.dianping.com/beijing/ch30" target="_blank" class="view-more" data-category="entertainment" data-click-title="全部按钮" data-click-name="全部">
#             <span class="more-desc">全部</span>
#             <span class="arrow-right"></span>
#         </a>
#     </div>
#     <div class="cata-con">
#             <div class="cata-shop-item">
#                 <div class="shop-item">
#                     <a href="//www.dianping.com/shop/l413eLzUKU426z5R" target="_blank" class="shop-img shop-item-pic" data-category="entertainment" data-click-title="图片" data-click-name="商家图片1" data-shopid="l413eLzUKU426z5R">
#                             <img lazy-src="https://p0.meituan.net/merchantpic/c7fdab20677ee99afa6faa26d6db0516490007.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" src="https://p0.meituan.net/merchantpic/c7fdab20677ee99afa6faa26d6db0516490007.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop/l413eLzUKU426z5R" target="_blank" class="shop-name" data-category="entertainment" data-click-title="标题" data-click-name="商家名称1" data-shopid="l413eLzUKU426z5R">
#                             <span class="name-desc">百汇盲人按摩</span>
#                         </a>
#                         <div class="star-info">
#                             <span class="star star-45"></span>
#                             <span class="comment">129条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">国贸/建外</span>
#                                 <span class="maincate-name">按摩/足疗</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥116/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="cata-shop-item">
#                 <div class="shop-item">
#                     <a href="//www.dianping.com/shop/G1WtdTkYGD4PrwLY" target="_blank" class="shop-img shop-item-pic" data-category="entertainment" data-click-title="图片" data-click-name="商家图片2" data-shopid="G1WtdTkYGD4PrwLY">
#                             <img lazy-src="https://p0.meituan.net/dpmerchantpic/567d4fba402dc49e81a4f9553513e4111238188.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" src="https://p0.meituan.net/dpmerchantpic/567d4fba402dc49e81a4f9553513e4111238188.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop/G1WtdTkYGD4PrwLY" target="_blank" class="shop-name" data-category="entertainment" data-click-title="标题" data-click-name="商家名称2" data-shopid="G1WtdTkYGD4PrwLY">
#                             <span class="name-desc">慢姑娘颐景墅主题别墅聚会轰趴馆</span>
#                         </a>
#                         <div class="star-info">
#                             <span class="star star-45"></span>
#                             <span class="comment">34条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">通州区</span>
#                                 <span class="maincate-name">轰趴馆</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥183/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="cata-shop-item">
#                 <div class="shop-item">
#                     <a href="//www.dianping.com/shop/k6hPGMwp0ZTaTXmh" target="_blank" class="shop-img shop-item-pic" data-category="entertainment" data-click-title="图片" data-click-name="商家图片3" data-shopid="k6hPGMwp0ZTaTXmh">
#                             <img lazy-src="https://p0.meituan.net/dpmerchantpic/a6e1f8dd1bc80250dfd604bcc265955446582.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" src="https://p0.meituan.net/dpmerchantpic/a6e1f8dd1bc80250dfd604bcc265955446582.jpg%40120w_90h_1e_1c_1l_80q%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="shop-info tag-no">
#                         <a href="//www.dianping.com/shop/k6hPGMwp0ZTaTXmh" target="_blank" class="shop-name" data-category="entertainment" data-click-title="标题" data-click-name="商家名称3" data-shopid="k6hPGMwp0ZTaTXmh">
#                             <span class="name-desc">老村凶宅沉浸式密室</span>
#                         </a>
#                         <div class="star-info">
#                             <span class="star star-35"></span>
#                             <span class="comment">32条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">青年路</span>
#                                 <span class="maincate-name">密室</span>
#
#                         </div>
#                         <div class="avg">
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="cata-shop-item">
#                 <div class="shop-item">
# ...
#                     <a href="//www.dianping.com/shop/H8kkSoT0yhTTr0bo" target="_blank" class="shop-item-pic" data-category="hotel" data-click-title="图片" data-click-name="商家图片3" data-shopid="H8kkSoT0yhTTr0bo">
#                             <img lazy-src="http://p0.meituan.net/tdchotel/6fe8f4b8745e090496f739e93367ea4b4864479.jpg%40340w_192h_1e_1l%7Cwatermark%3D0" src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="item-info">
#                         <a href="//www.dianping.com/shop/H8kkSoT0yhTTr0bo" target="_blank" class="shop-info tag-no shop-name" data-category="hotel" data-click-title="标题" data-click-name="商家名称3" data-shopid="H8kkSoT0yhTTr0bo">
#                         <span class="shop-name-desc">北京中国大饭店</span>
#                         </a>
#                         <div class="comment-info">
#                             <span class="star star-50"></span>
#                             <span class="shop-comment">1941条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">国贸/建外</span>
#                                 <span class="maincate-name">五星级酒店</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥1428/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="list-item">
#                 <div class="item">
#                     <a href="//www.dianping.com/shop/GaTjKDqCib1dDkEW" target="_blank" class="shop-item-pic" data-category="hotel" data-click-title="图片" data-click-name="商家图片4" data-shopid="GaTjKDqCib1dDkEW">
#                             <img lazy-src="http://p1.meituan.net/hotel/25720c0266a204a0e02e82ee61bcaf67619685.png%40340w_192h_1e_1l%7Cwatermark%3D0" src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="item-info">
#                         <a href="//www.dianping.com/shop/GaTjKDqCib1dDkEW" target="_blank" class="shop-info tag-no shop-name" data-category="hotel" data-click-title="标题" data-click-name="商家名称4" data-shopid="GaTjKDqCib1dDkEW">
#                         <span class="shop-name-desc">北京时光漫步酒店</span>
#                         </a>
#                         <div class="comment-info">
#                             <span class="star star-50"></span>
#                             <span class="shop-comment">1198条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">雍和宫/地坛</span>
#                                 <span class="maincate-name">舒适型</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥398/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="list-item">
#                 <div class="item">
#                     <a href="//www.dianping.com/shop/l2cf7A0ldhGvzwuw" target="_blank" class="shop-item-pic" data-category="hotel" data-click-title="图片" data-click-name="商家图片5" data-shopid="l2cf7A0ldhGvzwuw">
#                             <img lazy-src="https://qcloud.dpfile.com/pc/aPbfzzY94JQnp0jcFkICulAaThrpEb29VLxiV_85ukLQnOSSob9s5vYo9h12Ye8QkkCBOWO5rApRy3gE6VS0Vg.jpg" src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="item-info">
#                         <a href="//www.dianping.com/shop/l2cf7A0ldhGvzwuw" target="_blank" class="shop-info tag-no shop-name" data-category="hotel" data-click-title="标题" data-click-name="商家名称5" data-shopid="l2cf7A0ldhGvzwuw">
#                         <span class="shop-name-desc">北京诺金酒店</span>
#                         </a>
#                         <div class="comment-info">
#                             <span class="star star-50"></span>
#                             <span class="shop-comment">1259条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">酒仙桥</span>
#                                 <span class="maincate-name">豪华型</span>
#
#                         </div>
#                         <div class="avg">
#                                 <span>¥1494/人</span>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="list-item">
#                 <div class="item">
#                     <a href="//www.dianping.com/shop/G2FWP83c19TMOgaB" target="_blank" class="shop-item-pic" data-category="hotel" data-click-title="图片" data-click-name="商家图片6" data-shopid="G2FWP83c19TMOgaB">
#                             <img lazy-src="http://p0.meituan.net/tdchoteldark/1b67db97bb68ce3d37fde37580b3d15f494092.jpg%40340w_192h_1e_1l%7Cwatermark%3D0" src="//p1.meituan.net/gpa/8a011aaa356dc5cba2537cdd4400f1c09816.jpg" alt="商户图片">
#                         <div class="pic-overlay"></div>
#                     </a>
#                     <div class="item-info">
#                         <a href="//www.dianping.com/shop/G2FWP83c19TMOgaB" target="_blank" class="shop-info tag-no shop-name" data-category="hotel" data-click-title="标题" data-click-name="商家名称6" data-shopid="G2FWP83c19TMOgaB">
#                         <span class="shop-name-desc">北京小汤一瓢私汤度假酒店</span>
#                         </a>
#                         <div class="comment-info">
#                             <span class="star star-50"></span>
#                             <span class="shop-comment">195条评价</span>
#                         </div>
#                         <div class="area-info">
#                                 <span class="region-name">小汤山镇</span>
#                                 <span class="maincate-name">高档型</span>
#
#                         </div>
#                         <div class="avg">
#                         </div>
#                     </div>
#                 </div>
#             </div>
#     </div>
# </div>
#
#                     <!--旅游酒店模块结束-->
#                 </div>
#                 <div id="cata-nav" class="cata-nav" style="top: 279.5px; right: 1555px; display: none;">
#                     <div class="cata-nav-detail cata-part-one-nav" data-nav="cata-part-one">
#                         <a href="javascript:;" name="cata-part-one" data-click-name="吃喝玩乐">吃喝玩乐</a>
#                     </div>
#
#                         <div class="cata-nav-detail cata-part-two-nav nav-single" data-nav="cata-part-two">
#                             <a href="javascript:;" name="cata-part-two" data-click-name="结婚">结婚</a>
#                         </div>
#
#                     <div class="cata-nav-detail cata-part-three-nav beauty-nav-detail" data-nav="cata-part-three">
#                         <a href="javascript:;" name="cata-part-three" data-click-name="丽人亲子">丽人亲子</a>
#                     </div>
#
#                     <div class="cata-nav-detail cata-part-four-nav house-nav-detail nav-single" data-nav="cata-part-four">
#                         <a href="javascript:;" name="cata-part-four" data-click-name="家装">家装</a>
#                     </div>
#
#                     <div class="cata-nav-detail edu-cata-nav edu-nav-detail" data-nav="edu-cata">
#                         <a href="javascript:;" name="edu-cata" data-click-name="学习培训">学习培训</a>
#                     </div>
#
#
#                     <div class="cata-nav-detail service-cata-nav service-nav-detail" data-nav="service-cata">
#                         <a href="javascript:;" name="service-cata" data-click-name="生活服务">生活服务</a>
#                     </div>
#
#
#
#                     <div class="cata-nav-detail travel-hotel-cata-nav hotel-nav-detail" data-nav="travel-hotel-cata">
#                         <a href="javascript:;" name="travel-hotel-cata" data-click-name="旅游酒店">旅游酒店</a>
#                     </div>
#
#                      <div class="cata-nav-detail top-nav-detail nav-end current-nav" data-nav="header-container">
#                         <a href="javascript:;" name="header-container" data-click-name="顶部">顶部</a>
#                      </div>
#                 </div>
#             </div>
#             <!--页尾部分-->
#             <div class="footer-container">
#             <div id="index-footer" class="index-footer"> <div class="footer-links clearfix"> <div class="links-item"> <p class="link-title">商务合作</p> <ul class="link-panel"> <li class="link-li"><a rel="nofollow" target="_blank" href="//daili.meituan.com/?comeFrom=dpwebMenu">餐饮代理商招募</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="//b.dianping.com">商企通</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="//developer.meituan.com/?applyFrom=dianping_c_pc_home">聚宝盆商业开放平台</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="//pc.meituan.com/?activity_code=20_00039034">申请扫码点餐</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://zf.meituan.com?partnerSource=9">美团收单代理商招募</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://agent.meituan.com/zhaoshang?partnerSource=9">美团收银合作商招募</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="http://dpurl.cn/n/lKA3w">美团外卖代理商招募</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="//open.dianping.com">北极星商业开放平台</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="//paidui.meituan.com/?activity_code=166_00143140">免费使用美团排队</a></li> </ul> </div> <div class="links-item"> <p class="link-title">公司信息</p> <ul class="link-panel"> <li class="link-li"><a rel="nofollow" target="_blank" href="https://about.meituan.com/news/report?source=dp">媒体报道</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://about.meituan.com/">关于我们</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://about.meituan.com/investor.html">投资者关系</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://about.meituan.com/contact">联系我们</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://dpapp-appeal.meituan.com/#/shopCreditRegulationPC">商户诚信公约</a></li> <li class="link-li"><a target="_blank" href="//join.dianping.com">招聘</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://rules-center.meituan.com/rules-detail/8">餐饮安全管理办法</a></li> </ul> </div> <div class="links-item"> <p class="link-title">用户帮助</p> <ul class="link-panel"> <li class="link-li"><a target="_blank" href="//www.dianping.com/help">客户服务中心</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://ipr.meituan.com?source=2">知识产权维权</a></li> <li class="link-li"><a rel="nofollow" target="_blank" href="https://jubao.meituan.com/app/home?source=2">廉正举报平台</a></li> </ul> </div> <div class="links-item"> <p class="link-title">应用下载</p> <ul class="link-panel clearfix"> <a target="_blank" href="http://www.dianping.com/app/download"> <li class="qrcode-img"><i class="app-qrcode"></i> <p>扫码下载大众点评APP</p> </li> </a> </ul> </div> </div> <div class="footer-declare"> <div> <p class="company-desc"> <span class="all-right">©2003-2021 dianping.com, All Rights Reserved.</span> <span>本站发布的所有内容，未经许可，不得转载，详见 <a target="_blank" rel="nofollow" class="a-link" href="https://rules-center.meituan.com/rules-detail/69">《知识产权声明》</a> <a target="_blank" rel="nofollow" class="a-link" href="https://rules-center.meituan.com/rules-detail/11">《用户使用协议》</a> </span> </p> <p class="company-desc"> <span>增值电信业务经营许可证：</span> <a target="_blank" class="a-link" href="http://beian.miit.gov.cn" rel="nofollow">沪B2-20040012</a> <span class="all-right">|</span> <span>互联网药品信息服务资格： <a target="_blank" rel="nofollow" class="a-link" href="//p0.meituan.net/scarlett/cebbb4322510fd634840991620717bf2275115.jpg">(沪)-经营性-2017-0007</a> </span></p> </div> <div class="address"> <p class="company-desc"> <span>网络文化经营许可证： <a target="_blank" rel="nofollow" class="a-link" href="//p0.meituan.net/scarlett/a4ec049a9f1215757a8deee6aceb4f1c608734.jpg">沪网文[2020]0813-068号</a> </span> <span class="all-right">|</span> <span>用户举报热线：10100011</span> </p> </div> <p class="certify"> <a target="_blank" rel="nofollow" href="http://www.shjbzx.cn"> <i alt="违规信息举报" class="certify-img wgxxjb"></i> </a> <a target ...
#             </div>
#         </div>
#         <script>
#             function isIE(){
#                 var UA = navigator.userAgent;
#                 var browserName = navigator.appName;
#                 // edge appName 为 Netscape
#                 var isIE = browserName.indexOf('Microsoft Internet Explorer') !== -1;
#                 // 非IE浏览器则不考虑
#                 if (!isIE) return false;
#                 // IE8&IE8以下弹框
#                 var ieStr = /MSIE (\d+).0/g;
#                 // 检索IE版本
#                 var IEVersion = ieStr.exec(UA);
#                 if (IEVersion && IEVersion.length && IEVersion[1] < 9) {
#                     var IEPopHtml = '<div class="browser-overlay"></div><div id="browser-ie-con" class="browser-ie-con"><div id="browser-close" class="close">×</div><div class="browser-download chrome"><a href="//www.google.cn/chrome/browser/desktop/index.html?utm_dp" target="_black" title="chrome"></a></div><div class="browser-download firefox"><a href="//www.firefox.com.cn/download/?utm_dp" target="_black" title="firefox"></a></div></div>';
#                     // 插入DOM
#                     var _browser = document.createElement('div');
#                     _browser.id = 'browser-update-ie';
#                     _browser.className = 'browser-update-ie';
#                     _browser.innerHTML = IEPopHtml;
#                     document.getElementById('index-main').appendChild(_browser);
#                     // $('#index-main').append(IEPopHtml)
#                     var windowWidth = document.documentElement.clientWidth || document.body.clientWidth;
#                     var mainWidth = document.getElementById('browser-ie-con').offsetWidth;
#                     var popLeft = (windowWidth - mainWidth) / 2;
#                     document.getElementById('browser-ie-con').style.left = popLeft + 'px';
#                     // 绑定事件
#                     document.getElementById('browser-close').attachEvent('onclick', function() {
#                         document.getElementById('browser-update-ie').style.display = 'none'
#                     }, false)
#                 }
#             }
#             isIE()
#         </script>
#         <script type="text/javascript" src="//www.dpfile.com/app/pc-common/index.min.7d164b78c00bdf53d69c6e8fb3259600.js"></script>
# <script src="//www.dpfile.com/app/dpindex-new-static/static/manifest.min.2aa11b4885e54f31cc647e6dc60e38ee.js" type="text/javascript"></script><script src="//www.dpfile.com/app/dpindex-new-static/static/common.min.914fa42caf7c1784bdd51fad93a70c30.js" type="text/javascript"></script><script src="//www.dpfile.com/app/dpindex-new-static/static/index.min.b471ad66de835388bcec00199e7296e9.js" type="text/javascript"></script>        <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl.min.cda8ec4ee5c8d7782067c521a57023bf.js"></script>
#         <script>
#             Owl.start({
#                 // 建议使用前端项目名，package.json或者f2eci.json中的name
#                 project: 'pc-new',
#                 /* 强烈建议业务进行配置，有利于数据的聚合
#                  * 当前页面所属的页面URL，默认会使用window.location.href
#                  * 建议不要直接使用location.href,
#                  * 可以是非URL，比如'toutiao-detail'
#                  */
#                 pageUrl: 'pc-index-new'
#             })
#         </script>
#         <script>
#             var rohrdata = "";
#             var Rohr_Opt = new Object;
#             Rohr_Opt.Flag = 100070;
#             Rohr_Opt.LogVal = "rohrdata";
#         </script>
#         <script defer="" src="https://s0.meituan.net/mx/rohr/rohr.min.js"></script>
#
#
# </body></html>

# %% [markdown]
# ### 第二次尝试

# %%
import re
import os
import time
import random

import requests
from selenium import webdriver


def download_html(url: str, file: str):
    """
    利用selenium框架调用浏览器，下载js渲染后的页面代码
    :param url: 网址
    :param file: html文件名字
    :return:
    """
    # 这里我调用的是FireFox来渲染网页，大家也可以用其它浏览器来渲染页面，不过要下载对应得驱动才行
    # FireFox驱动下载：https://github.com/mozilla/geckodriver/releases
    # Google Chrome：http://npm.taobao.org/mirrors/chromedriver/
#     driver = webdriver.Firefox(executable_path=r'geckodriver.exe')  # 调用驱动，我的浏览器版本78.0.2
    options = webdriver.ChromeOptions()
    options.add_argument(r"user-data-dir=C:\Users\45207\AppData\Local\Google\Chrome\User''Data\Default\Login''Data")
    options.add_experimental_option('debuggerAddress','127.0.0.1:9222')
    driver = webdriver.Chrome(executable_path=r"C:\Users\45207\anaconda3\Scripts\chromedriver.exe",port=0,options=options)    
    driver.get(url)  # 加载网页

    time.sleep(30)  # 暂停30s,在这个时间内进行登陆操作

    driver.find_element_by_class_name('fold').click()  # 触发点击操作
    time.sleep(2)
    with open(file, 'w', encoding='utf-8') as f:  # 下载网页
        f.write(driver.page_source)
    driver.close()


def download_css(html: str, css: str):
    """
    根据网页下载css文件
    :param html:
    :param css:
    :return:
    """
    with open(html, 'r', encoding='utf-8') as f:
        html = f.read()

    css_url = re.findall('<link rel="stylesheet" type="text/css" href="(.*?)">', html, re.S)  # 提取链接
    css_url = 'http:{}'.format(css_url[1])
    css_content = requests.get(css_url).text
    with open(css, 'w', encoding='utf-8') as f:  # 保存css文件
        f.write(css_content)


def down_load_fontLibrary(css: str, fontLibrary: str):
    """
    根据css文件下载字体库
    :param css: css文件
    :param fontLibrary: 下载的字体库文件名字
    :return:
    """
    with open(css, 'r', encoding='utf-8') as f:
        css_content = f.read()

    font = re.findall('background-image: url\((.*?)\);', css_content, re.S)  # 提取链接
    font_url = 'http:{}'.format(font[1])
    font_content = requests.get(font_url).text
    with open(fontLibrary, 'w', encoding='utf-8') as f:  # 保存文件
        f.write(font_content)


def restore_text(css: str, font_library: str, html: str):
    """
    还原原始评论
    :param css: 用于加密的css文件
    :param fontLibrary: 字体库文件
    :param html: 原始html文件
    :return:
    """
    with open(css, 'r', encoding='utf-8') as f:
        css = f.read()

    with open(html, 'r', encoding='utf-8') as f:
        html = f.read()

    with open(font_library, 'r', encoding='utf-8') as f:
        font_library = f.read()

    inf = re.findall('<div class="review-words(.*?)<div class="less-words">', html, re.S)
    for record in inf:
        inf_copy = record
        svgmti = re.findall('<svgmtsi class="(.*?)">', record)
        for class_name in svgmti:
            XY = re.findall('.%s{background:-(.*?)px -(.*?)px;}' % class_name, css, re.S)
            X = int(float(XY[0][0]) / 14)  # 被替换的文字X坐标换算为字体库的X
            Y = int(float(XY[0][1]) + 23)  # 被替换的文字Y坐标换算为字体库的Y
            fo = re.findall('<text x="0" y="%s">(.*?)</text>' % Y, font_library)
            inf_copy = re.sub(f'<svgmtsi class="{class_name}"></svgmtsi>', fo[0][X], inf_copy, count=0)

        # 删除干扰字符
        inf_copy = re.sub('<img .*? alt="">', '', inf_copy, count=0)
        inf_copy = re.sub('</div>.*?<div class="review-words', '', inf_copy, count=0, flags=re.S)
        inf_copy = inf_copy.replace('Hide">', '')
        inf_copy = inf_copy.replace('">', '')
        inf_copy = inf_copy.replace('\n', '')
        inf_copy = inf_copy.replace(' ', '')
        inf_copy = inf_copy.strip()

        print(inf_copy)


def create_folder():
    """
    检测当前目录下是否创建了这三个文件夹，没有则创建
    :return:
    """
    ls = os.listdir()
    if "html" not in ls:
        os.mkdir("html")

    if "css" not in ls:
        os.mkdir("css")

    if "font" not in ls:
        os.mkdir("font")


def main():
    """
    主程序
    :return:
    """
    create_folder()
    url = 'http://www.dianping.com/shop/kaiOj6rNZxW6HVO1/review_all/p{}'
    
    for i in range(1, 3):
        download_html(url.format(i), "html/p1.html")
        download_css("html/1.html", "css/font.css")
        down_load_fontLibrary("css/font.css", "font/font.swg")

    for i in range(1, 3):
        restore_text("css/font.css", "font/font.swg", f"html/p{i}.html")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-471f36bd0577> in <module>
#     142
#     143 if __name__ == "__main__":
# --> 144     main()
#
# <ipython-input-1-471f36bd0577> in main()
#     134     for i in range(1, 3):
#     135         download_html(url.format(i), "html/p1.html")
# --> 136         download_css("html/1.html", "css/font.css")
#     137         down_load_fontLibrary("css/font.css", "font/font.swg")
#     138
#
# <ipython-input-1-471f36bd0577> in download_css(html, css)
#      41     :return:
#      42     """
# ---> 43     with open(html, 'r', encoding='utf-8') as f:
#      44         html = f.read()
#      45
#
# FileNotFoundError: [Errno 2] No such file or directory: 'html/1.html'
