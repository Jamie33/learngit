# %%
#encoding=utf8
import re
import requests

from bs4 import BeautifulSoup



url = 'http://tieba.baidu.com/f?ie=utf-8&kw=%E8%99%9A%E6%8B%9F%E5%B8%81&fr=search&red_tag=l2306181970'


header = { 
    'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
    }


thread_url = 'http://tieba.baidu.com/p/5439419607?pn=1'
data = requests.get(thread_url,headers = header)

soup = BeautifulSoup(data.text,'html.parser')

print(soup)

reg = r'[A-Za-z0-9.]+@[A-Za-z0-9]+\.[a-z]{1,3}'
emails = re.findall(reg,str(soup))
#print(emails)

page_reg = r'共<span class="red">4</span>页</li>'
page = re.search(page_reg,str(soup))
print(page)
# Out:
# <!DOCTYPE HTML>
# ...

# %%
#encoding=utf8
import re
import requests
from pyquery import PyQuery as pq




url = 'http://tieba.baidu.com/f?ie=utf-8&kw=%E8%99%9A%E6%8B%9F%E5%B8%81&fr=search&red_tag=l2306181970'


header = { 
    'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
    }


thread_url = 'http://tieba.baidu.com/p/5439419607?pn=1'
doc = pq(thread_url,headers = header)

page = doc('.skin_normal')
print(page)

# %%
from selenium import webdriver
import time
import datetime
from threading import Timer

def baidu():
   
 
    thread_url = 'http://tieba.baidu.com/p/5439419607?pn=1'
    driver = webdriver.Chrome()  #声明浏览器对象
    driver.get(thread_url) # 访问网页
    driver.implicitly_wait(5) # 隐式等待
    content = driver.find_element_by_class('p_postlist')
    print(content.text)
        
        
        
    


baidu()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-f5ea5179a431> in <module>()
#      19
#      20
# ---> 21 baidu()
#
# <ipython-input-71-f5ea5179a431> in baidu()
#      11     driver.get(thread_url) # 访问网页
#      12     driver.implicitly_wait(5) # 隐式等待
# ---> 13     content = driver.find_element_by_class('p_postlist')
#      14     print(content.text)
#      15
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_class'
