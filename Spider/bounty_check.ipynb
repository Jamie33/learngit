# %% [markdown]
# ## check real followers of twitter

# %%
from pyquery import PyQuery as pq
import csv
from selenium import webdriver


username = ''
password = ''

proxie = {'https':'https://127.0.0.1:1080'}
prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
options.add_experimental_option('prefs',prefs)
driver = webdriver.Chrome(chrome_options=options)
driver.get('https://www.twitteraudit.com/')
driver.find_element_by_css_selector('a.button.button--white').click()
driver.implicitly_wait(50)
driver.find_element_by_id('username_or_email').send_keys(username)
driver.find_element_by_id('password').send_keys(password)
driver.find_element_by_id('allow').click()
driver.implicitly_wait(50)


def get_stake(number):
    
    if number > 10000:
        stake = 8
    elif number > 5000:
        stake = 5
    elif number > 3000:
        stake = 3
    elif number > 1000:
        stake = 2
    elif number>=20 or number<=1000: 
        stake = 1 
    return stake

filename = r'NAUS ALL IN SPREADSHEAT - TWITTER0827.csv'
with open('Twiiter Audit Stake0827.csv','a',encoding='utf-8') as w:
    with open(filename,'r',encoding='utf-8') as f:
        reader = csv.reader(f)
        urls = [row[5] for row in reader]
        for url in urls[1:]:
            
            try:
                doc = pq(url)
                number = int(doc('.color--green-base .real.number').attr('data-value'))
                if number > 10000:
                    stake = 8
                elif number > 5000:
                    stake = 5
                elif number > 3000:
                    stake = 3
                elif number > 1000:
                    stake = 2
                elif number>=20 or number<=1000: 
                    stake = 1   
            except:
                try:
                    driver.get(url)
                    driver.find_element_by_css_selector('span.white-space--nowrap').click()
                    driver.implicitly_wait(50)
                    number = driver.find_element_by_css_selector('span.real.number').text
                    if number > 10000:
                        stake = 8
                    elif number > 5000:
                        stake = 5
                    elif number > 3000:
                        stake = 3
                    elif number > 1000:
                        stake = 2
                    elif number>=20 or number<=1000: 
                        stake = 1 
                except:
                    number ='wrong audit url'
                    stake = 0
            print(url,number,stake)
            w.write('{},{},{}\n'.format(url,number,stake))
print('done')
# Out:
# https://www.twitteraudit.com/6y8NDB5RAsFD2Z3 3940 3
# https://www.twitteraudit.com/taraspinchak 2052 2
# https://www.twitteraudit.com/funny_models 11062 8
# https://www.twitteraudit.com/holdyourcolors 6038 5
# https://www.twitteraudit.com/barinovo619 2928 2
# https://www.twitteraudit.com/mps_olga 10086 8
# https://www.twitteraudit.com/JeremyDuglas 4116 3
# https://t.me/Shakawat8925 wrong audit url 0
# https://www.twitteraudit.com/Mcdelan25 779 1
# https://www.twitteraudit.com/artsobol33 4652 3
# https://www.twitteraudit.com/eklomanova1 4134 3
# https://www.twitteraudit.com/Dhanems1 3542 3
# https://www.twitteraudit.com/lizmarkova11 2941 2
# https://www.twitteraudit.com/wahabbounty 3911 3
# https://www.twitteraudit.com/noviaexo1 5823 5
# https://www.twitteraudit.com/Milonsa2 3582 3
# https://www.twitteraudit.com/JayraldRegado 2017 2
# https://www.twitteraudit.com/carlawsssss 3325 3
# https://www.twitteraudit.com/espritman999 5387 5
# https://www.twitteraudit.com/ledat1612 2435 2
# ...

# %%
import csv

filename = r'NAUS ALL IN SPREADSHEAT - TWITTER.csv'
with open(filename,'r',encoding='utf-8') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row[5])
# Out:
# Audit
# https://www.twitteraudit.com/6y8NDB5RAsFD2Z3
# https://www.twitteraudit.com/taraspinchak
# https://www.twitteraudit.com/funny_models
# https://www.twitteraudit.com/holdyourcolors
# https://www.twitteraudit.com/barinovo619
# https://www.twitteraudit.com/mps_olga
# https://www.twitteraudit.com/JeremyDuglas
# https://t.me/Shakawat8925
# https://www.twitteraudit.com/Mcdelan25
# https://www.twitteraudit.com/artsobol33
# https://www.twitteraudit.com/eklomanova1
# https://www.twitteraudit.com/Dhanems1
# https://www.twitteraudit.com/lizmarkova11
# https://www.twitteraudit.com/wahabbounty
# https://www.twitteraudit.com/noviaexo1
# https://www.twitteraudit.com/Milonsa2
# https://www.twitteraudit.com/JayraldRegado
# https://www.twitteraudit.com/carlawsssss
# https://www.twitteraudit.com/espritman999
# https://www.twitteraudit.com/ledat1612
# https://www.twitteraudit.com/IvanRuzv
# https://www.twitteraudit.com/kwakyeBenjamin7
# https://www.twitteraudit.com/MarfowaahCecil1
# ...

# %% [markdown]
# ## twitter follow or not

# %% [markdown]
# ## 获取官方twitter全部粉丝

# %%
import tweepy
from tweepy import OAuthHandler
import time

consumer_key = 'kDMX2rApBKm1D2kCy0NfeW4Ru'
consumer_secret = 'wrnmQvH90gB0Req3Q5lnm6ruNercTyFjeLHlb6sETfeCPKZX4N'
access_token = '3272682498-PcewubomkAKDoDyxQVhk5wCdKWqIaN8ykjOAaUI'
access_secret = 'F3unOH8LobxrhZOHL36DMOydwHtKDQs4ZFcvRN0SimfwN'


auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth,proxy='https://127.0.0.1:1080')
num = 0

with open('twitterfollwers0906.txt','w',encoding='utf-8') as w:
    for user in tweepy.Cursor(api.followers,screen_name = 'NausGlobal',count =200 ).items():
        w.write(user.screen_name)
        num += 1

print('done')
print('twitter 账户总粉丝数',num)
# Out:
# done
# twitter 账户总粉丝数 1254

# %% [markdown]
# ## 检查用户是否关注官方twitter

# %%
import csv 


filename = r'NAUS ALL IN SPREADSHEAT - TWITTER0906.csv'

with open('twitterfollowerverfiy0906.csv','a',encoding='utf-8') as w:
    with open('twitterfollwers0906.txt','r',encoding='utf-8') as r:
        content = r.read()
        with open(filename,'r',encoding='utf-8') as f:
            reader = csv.reader(f)
            urls = [row[3] for row in reader]
            for url in urls[1:]:
                name = url.split('/')[-1].strip('')
                if name in content:
                    status = 'follow'
                else:
                    status = 'not follow'
                w.write('{},{},{}\n'.format(url,name,status))
print('done')
# Out:
# done

# %% [markdown]
# ## 检查未follow的用户是否关注官方twitter

# %%
import csv 


filename = r'NAUS ALL IN SPREADSHEAT - TWITTER0906.csv'

with open('twitterfollowerverfiy0906.csv','a',encoding='utf-8') as w:
    with open('twitterfollwers0906.txt','r',encoding='utf-8') as r:
        content = r.read()
        with open(filename,'r',encoding='utf-8') as f:
            reader = csv.DictReader(f)
            i = 0
            for row in reader:
                if row['follow NAUS or not'] == 'not follow':
                        i += 1
                        print('正在检查第{}个用户......'.format(i))
                        name = row['Audit'].split('/')[-1].strip('')
                        if name in content:
                            status = 'follow'
                        else:
                            status = 'not follow'
                        w.write('{},{},{}\n'.format(row['Audit'],name,status))
print('done')
# Out:
# 正在检查第1个用户......
# 正在检查第2个用户......
# 正在检查第3个用户......
# 正在检查第4个用户......
# 正在检查第5个用户......
# 正在检查第6个用户......
# 正在检查第7个用户......
# 正在检查第8个用户......
# 正在检查第9个用户......
# 正在检查第10个用户......
# 正在检查第11个用户......
# 正在检查第12个用户......
# 正在检查第13个用户......
# 正在检查第14个用户......
# 正在检查第15个用户......
# 正在检查第16个用户......
# 正在检查第17个用户......
# 正在检查第18个用户......
# 正在检查第19个用户......
# 正在检查第20个用户......
# 正在检查第21个用户......
# 正在检查第22个用户......
# 正在检查第23个用户......
# 正在检查第24个用户......
# 正在检查第25个用户......
# 正在检查第26个用户......
# 正在检查第27个用户......
# 正在检查第28个用户......
# 正在检查第29个用户......
# 正在检查第30个用户......
# 正在检查第31个用户......
# 正在检查第32个用户......
# 正在检查第33个用户......
# 正在检查第34个用户......
# 正在检查第35个用户......
# 正在检查第36个用户......
# 正在检查第37个用户......
# 正在检查第38个用户......
# 正在检查第39个用户......
# 正在检查第40个用户......
# 正在检查第41个用户......
# 正在检查第42个用户......
# 正在检查第43个用户......
# 正在检查第44个用户......
# 正在检查第45个用户......
# 正在检查第46个用户......
# 正在检查第47个用户......
# 正在检查第48个用户......
# 正在检查第49个用户......
# 正在检查第50个用户......
# 正在检查第51个用户......
# 正在检查第52个用户......
# 正在检查第53个用户......
# ...

# %% [markdown]
# ## Facebook friends

# %%
import requests
from bs4 import BeautifulSoup
from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

proxie = {
    'http':'http://127.0.0.1:1080',
    'https':'https://127.0.0.1:1080'}

header = { 
    'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
    }

url = 'https://www.facebook.com/Daniel.Hunter686'
data = requests.get(url,headers = header,verify=False,proxies = proxie)
soup = BeautifulSoup(data.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
from selenium import webdriver
import csv
import time
from random import randint

def facebook(username,password):

    proxie = {'https':'https://127.0.0.1:1080'}
    prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('https://www.facebook.com/')
    
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(200)
    
    with open('NAUS ALL IN SPREADSHEAT - FACEBOOK0906.csv','r',encoding='utf-8') as r:
        with open('FacebookFriends.csv','a',encoding='utf-8') as w:
            reader = csv.reader(r)
            urls = [row[3] for row in reader]
            for url in urls[163:]:
                time.sleep(randint(10,20))
                name = url.split('/')[-1].strip('')
                driver.get('https://www.facebook.com/{}'.format(name))
                driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
                driver.implicitly_wait(200)
                try:
                    number = driver.find_element_by_css_selector('span._50f8._2iem').text
                    if ',' in number:
                        friends = int(''.join(number.split(',')))
                    else:
                        friends = int(number)
                    
                    if friends > 10000:
                        stake = 8
                    elif friends > 5000:
                        stake = 5
                    elif friends > 3000:
                        stake = 3
                    elif friends > 1000:
                        stake = 2
                    elif friends >=20 or friends<=1000: 
                        stake = 1 
                    
                except Exception as e:
                    print(e)
                    friends = "didn't get friends"
                    stake = 0 
                
                print(name,friends,stake)
                w.write('{},{},{},{}\n'.format(url,name,friends,stake))
                driver.quit()
                
url = 'https://www.facebook.com/'
username = ''
password = ''


facebook(username,password)

# %%
from selenium import webdriver
import csv
import time

def facebook(username,password):

    proxie = {'https':'https://127.0.0.1:1080'}
    prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('https://www.facebook.com/')
    
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(10)
    
  
    driver.get('https://www.facebook.com/pg/NAUSOFFICIAL/reviews/')
    target = driver.find_element_by_css_selector('div.mvl.copyright')
    
    for i in range(18):
        driver.execute_script('arguments[0].scrollIntoView();',target)
        time.sleep(5)
        
    driver.implicitly_wait(10)
    list = driver.find_element_by_id('recommendations_tab_main_feed').text

    with open('NAUS ALL IN SPREADSHEAT - FACEBOOK0906.csv','r',encoding='utf-8') as r:
        with open('FACEBOOK recommand0907.csv','a',encoding='utf-8') as w:
            reader = csv.reader(r)
            urls = [row[3] for row in reader]
            for url in urls[201:]:
                name = url.split('/')[-1].strip('')
                driver.get('https://www.facebook.com/{}'.format(name))
                driver.implicitly_wait(200)
                try:
                    driver.implicitly_wait(200)
                    username = driver.find_element_by_css_selector('a._2nlw._2nlv').text.replace('\n','')
                    if '(' in username:
                        username = username.split('(')[0]
                    if username in list:
                        status = 'recommend with comment'
                    else:
                        status = 'not recommend'
                except Exception as e:
                    print(e)
                    status = 'something went wrong' 
                    user = "didn't get name"
                    
                print(username,status)
                w.write('{},{},{}\n'.format(url,username,status))
        driver.quit()
    print('done') 

url = 'https://www.facebook.com/'
username = ''
password = ''


facebook(username,password)
# Out:
# Snezhana Tsvetkova not recommand
# Olga Sivok not recommand
# Margarita Krylova not recommand
# Анастасия Ковалева not recommand
# Mostafijur Rahman not recommand
# Toheed Saeed not recommand
# Алексей Моисеев not recommand
# Cynthia Chinahota recommand with comment
# Denis Kustov not recommand
# Ni Dwi recommand with comment
# Roman Holubets not recommand
# Hamilton Danes not recommand
# Сергей Михайлов not recommand
# Saepul Muhtadin not recommand
# Amaya Sahangi not recommand
# Sithumi Nimasha not recommand
# Артём Архипов not recommand
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"a._2nlw._2nlv"}
#   (Session info: chrome=66.0.3359.139)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# Артём Архипов something went wrong
# Gia Hân recommand with comment
# Oleg Ilga not recommand
# Dmitriy Agapitov recommand with comment
# Alex Konichenko not recommand
# ...

# %%
from selenium import webdriver
import csv
import time

def facebook(username,password):

    proxie = {'https':'https://127.0.0.1:1080'}
    prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('https://www.facebook.com/')
    
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(10)
    
  
    driver.get('https://www.facebook.com/pg/NAUSOFFICIAL/reviews/')
    target = driver.find_element_by_css_selector('div.mvl.copyright')
    
    for i in range(18):
        driver.execute_script('arguments[0].scrollIntoView();',target)
        time.sleep(5)
        
    driver.implicitly_wait(10)
    list = driver.find_element_by_id('recommendations_tab_main_feed').text
    
    with open('NAUS FACEBOOK Recommendations0907.txt','w',encoding='utf-8') as f:
        f.write(list)

    with open('NAUS ALL IN SPREADSHEAT - FACEBOOK0906.csv','r',encoding='utf-8') as r:
        with open('FACEBOOK recommend0907.csv','a',encoding='utf-8') as w:
            reader = csv.reader(r)
            names = [row[10] for row in reader]
            for username in names[1:]:
                if username in list:
                    status = 'recommend with comment'
                else:
                    status = 'not recommend'
                    
                print(username,status)
                w.write('{},{}\n'.format(username,status))
        driver.quit()
    print('done') 

url = 'https://www.facebook.com/'
username = '452070961@qq.com'
password = 'Jamie8449671'


facebook(username,password)
# Out:
# Daniel Hunter recommand with comment
# Taras Siruy recommand with comment
# Анатолий Феймин recommand with comment
# Oleg Barinov not recommand
# Lisa Julian not recommand
# Tasfiha Bin Mannat not recommand
# Maria Christina Delan recommand with comment
# Artem Sobolev not recommand
# Fara Dita Lutfiana not recommand
# Ekaterina Lomanova not recommand
# Emely Race recommand with comment
# Abdul Wahab recommand with comment
# Liza Markova not recommand
# Rupa Rupa not recommand
# Jayrald Flores Regado not recommand
# Mjonel SaLes Samillano not recommand
# Nadia Afrin not recommand
# Lê ??t not recommand
# N'nenkz Rizha Smailee not recommand
# Ivan Ruzvelt not recommand
# Dexter Cargullo recommand with comment
# Igp Real not recommand
# Daise Ohenewaah not recommand
# Юлия Коновалова not recommand
# Ahmd Ibrahim not recommand
# Moh Novel Asy'ari not recommand
# V? Hà My not recommand
# Fakrijal Ahlul Nazar not recommand
# Quang Huy Nguyen recommand with comment
# ...

# %%
from selenium import webdriver
import csv
import time

def facebook(username,password):

    proxie = {'https':'https://127.0.0.1:1080'}
    prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('https://www.facebook.com/')
    
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(10)
    
  
    driver.get('https://www.facebook.com/pg/NAUSOFFICIAL/reviews/')
    target = driver.find_element_by_css_selector('div.mvl.copyright')
    
    for i in range(14):
        driver.execute_script('arguments[0].scrollIntoView();',target)
        time.sleep(5)
        
    driver.implicitly_wait(10)
    list = driver.find_element_by_id('recommendations_tab_main_feed').text
    
    with open('NAUS FACEBOOK Recommendations0827.txt','w',encoding='utf-8') as f:
        f.write(list)

    
 
    driver.quit()
    print('done') 

url = 'https://www.facebook.com/'
username = ''
password = ''


facebook(username,password)
# Out:
# done

# %%
with open('NAUS FACEBOOK Recommendations0907.txt','r',encoding='utf-8') as r:
        content = r.read()
        if 'Роман Медник' in content:
            print('True')
        else:
            print('False')
# Out:
# False

# %%
from selenium import webdriver
import csv
import time
from random import randint

def facebook(username,password):

    proxie = {'https':'https://127.0.0.1:1080'}
    prefs = {'profile.default_content_setting_values':
            {
            'notifications':2
            }
    }
    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('https://www.facebook.com/')
    
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(10)
    
  
    with open('NAUS FACEBOOK Recommendations0827.txt','r',encoding='utf-8') as t:
        content = t.read()
        with open('NAUS ALL IN SPREADSHEAT - FACEBOOK0827.csv','r',encoding='utf-8') as r:
            with open('FACEBOOK recommand0828.csv','a',encoding='utf-8') as w:
                reader = csv.reader(r)
                urls = [row[3] for row in reader]
                for url in urls[1:]:
                    name = url.split('/')[-1].strip('')
                    driver.get('https://www.facebook.com/{}'.format(name))
                    driver.implicitly_wait(200)
                    try:
                        
                        time.sleep(randint(10,30))
                        username = driver.find_element_by_css_selector('a._2nlw._2nlv').text.replace('\n','')
                        if '(' in username:
                            username = username.split('(')[0].strip()
                        if username in content:
                            status = 'recommand with comment'
                        else:
                            status = 'not recommand'
                    except Exception as e:
                        print(e)
                        username = "didn't get the name"
                        status = 'something went wrong' 

                    print(username,status)
                    w.write('{},{},{}\n'.format(url,username,status))
            driver.quit()
    print('done') 


url = 'https://www.facebook.com/'
username = ''
password = ''


facebook(username,password)
# Out:
# Daniel Hunter recommand with comment
# Taras Siruy recommand with comment
# Анатолий Феймин recommand with comment
# Oleg Barinov not recommand
# Lisa Julian not recommand
# Tasfiha Bin Mannat not recommand
# Maria Christina Delan recommand with comment
# Artem Sobolev not recommand
# Fara Dita Lutfiana not recommand
# Ekaterina Lomanova not recommand
# Emely Race not recommand
# Abdul Wahab recommand with comment
# Liza Markova not recommand
# Rupa Rupa not recommand
# Jayrald Flores Regado not recommand
# Mjonel SaLes Samillano not recommand
# Nadia Afrin not recommand
# Lê Đạt not recommand
# N'nenkz Rizha Smailee not recommand
# Ivan Ruzvelt not recommand
# Dexter Cargullo recommand with comment
# Igp Real not recommand
# Daise Ohenewaah not recommand
# Юлия Коновалова not recommand
# Ahmd Ibrahim not recommand
# Moh Novel Asy'ari not recommand
# Võ Hà My not recommand
# Fakrijal Ahlul Nazar not recommand
# Quang Huy Nguyen recommand with comment
# Vinay Bit not recommand
# ...

# %% [markdown]
# ## bounty thread check

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)


def check_tweet(url,name):
    print('当前twitter用户名:{}\n检查BTTurl:{}'.format(name,url))
    
    proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

    header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

    prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }

    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    
    with open('tweetscheck0903.csv','a',encoding='utf-8') as w:
        number = 0 
        try:
            thread_number = url.split('#')[-1]
            data = requests.get(url,headers = header,verify=False,proxies = proxie)
            soup = BeautifulSoup(data.text,'html.parser')
            #reply = soup.find(attrs={'name':thread_number}).parent
            reply = soup.find(attrs={'href':url}).parent
            content = reply.select('.post')
            twitter_reg = 'https://.*?twitter.com/'+name+'/status/\d+'
            tweet_url = set(re.findall(twitter_reg,str(content)))
            
            reply = soup.find(attrs={'href':url}).parent
        except:
            #print(url,'用户提供的链接有问题')
            status = '用户提供的帖子链接有问题'
        else:
            
            if len(tweet_url) == 0:
                #print(url,'当前帖子无推文链接')
                status = '当前帖子无推文链接'
            else:   

                for i in tweet_url:
                    try:
                        driver.get(i)
                        content = driver.find_element_by_css_selector('.permalink-inner.permalink-tweet-container').text
                        time.sleep(randint(1,10))
                    except:
                        pass
                        #print(i,'推文链接有问题')
                        status = '推文链接有问题'
                    else:
                        if 'NAUS' or 'NausGlobal' in content:
                            #print(i,'right tweet')
                            number += 1
                            status = '推文内容正确'
                        else:
                            #print(i,'wrong tweet')
                            status = '推文内容错误'
                        
                
                #print('有效推文数：',number)
                driver.quit()
        print(url,number,status)
        w.write('{},{},{}\n'.format(url,number,status))
        



    
filename = r'NAUS ALL IN SPREADSHEAT - TWITTER0903.csv'

print('检查帖子tweet有效数开始')

with open(filename,'r',encoding='utf-8') as f:    
        reader = csv.DictReader(f)
        for row in reader:
            check_tweet(row['Authenticator  Post'],row['twiiter username'])

            
print('检查完成')
# Out:
# 检查帖子tweet有效数开始
# 当前twitter用户名:6y8NDB5RAsFD2Z3
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43139566#msg43139566
# https://bitcointalk.org/index.php?topic=4778587.msg43139566#msg43139566 当前帖子无推文链接
# 当前twitter用户名:taraspinchak
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43142404#msg43142404
# https://twitter.com/taraspinchak/status/1024250364609155072 推文链接有问题
# https://twitter.com/taraspinchak/status/1023999797882175488 推文链接有问题
# https://twitter.com/taraspinchak/status/1024251000704720896 推文链接有问题
# https://twitter.com/taraspinchak/status/1024614591299575808 推文链接有问题
# https://twitter.com/taraspinchak/status/1024614151933636608 推文链接有问题
# https://twitter.com/taraspinchak/status/1025343049654824960 推文链接有问题
# https://twitter.com/taraspinchak/status/1024949181197307904 推文链接有问题
# 有效推文数： 0
# 当前twitter用户名:funny_models
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43143339#msg43143339
# ...

# %% [markdown]
# ## Facebook thread check

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }

options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
options.add_experimental_option('prefs',prefs)
driver = webdriver.Chrome(chrome_options=options)
    


def check_post(url):
    print('当前检查BTTurl:{}'.format(url))
    

    with open('Facebookpostcheck0906.csv','a',encoding='utf-8') as w:
        share_number = 0 
        comment_number = 0
        try:
            thread_number = url.split('#')[-1]
            data = requests.get(url,headers = header,verify=False,proxies = proxie)
            soup = BeautifulSoup(data.text,'html.parser')
            reply = soup.find(attrs={'href':url}).parent.parent.parent.parent
            links = '\n'.join(set(re.findall('href="(.+?)"',str(reply))))
            
            fb_share = 'https://\w{3}.facebook.com/[^NAUSOFFICIAL\n]+?/posts/\d+'
            fb_comment = '(https://\w{3}.facebook.com/NAUSOFFICIAL/posts/.+?comment_id=.*?comment_tracking=.*?D)|(https://\w{3}.facebook.com/NAUSOFFICIAL/posts/.+?comment_id.*?)' 

            share_url = set(re.findall(fb_share,links))
            comment = set(re.findall(fb_comment,links))
            weeks = str(reply).lower().count('week')

        except:
            print(url,'用户提供的链接有问题')
            status = '用户提供的帖子链接有问题'
            
        else:
            comment_number = len(comment)
            if len(share_url) == 0:
                print(url,'当前帖子无分享链接')
                status = '当前帖子无分享链接'
            else:   

                for i in (share_url):
                    time.sleep(randint(5,20))
                    try:
                        driver.get(i)
                        content = driver.find_element_by_css_selector('div._1dwg._1w_m._q7o').text
                    except:
                        pass
                        print(i,'分享链接有问题')
                        status = '分享链接有问题'
                    else:
                        if 'NAUS'in content:
                            print(i,'right share')
                            status = '帖子分享有效'
                            share_number += 1
                        else:
                            print(i,'wrong share')
                            status = '帖子分享无效'
                
                print('有效分享数：',share_number,'有效评论数：',comment_number,'参与周数:'，weeks)
        
        print(url,share_number,comment_number,status)
        w.write('{},{},{},{}\n'.format(url,share_number,comment_number,status))
        


username = ''
password = ''
    
driver.get('https://www.facebook.com/NAUSOFFICIAL')
driver.find_element_by_id('email').send_keys(username)
driver.find_element_by_id('pass').send_keys(password)
driver.find_element_by_id('loginbutton').submit()
driver.implicitly_wait(10)
    
filename = r'NAUS ALL IN SPREADSHEAT - FACEBOOK0906.csv'

print('检查帖子Facebook post有效数开始......')

with open(filename,'r',encoding='utf-8') as f:    
        reader = csv.DictReader(f)
        i = 0
        for row in reader:
            i += 1
            print('正在检查第{}个帖子......'.format(i))
            check_post(row['Authenticator  Post'])

driver.quit()            
print('检查完成')
# Out:
# 检查帖子Facebook post有效数开始......
# 正在检查第1个帖子......
# 当前检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43139566#msg43139566
# https://bitcointalk.org/index.php?topic=4778587.msg43139566#msg43139566 当前帖子无分享链接
# https://bitcointalk.org/index.php?topic=4778587.msg43139566#msg43139566 0 0 当前帖子无分享链接
# 正在检查第2个帖子......
# 当前检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43142404#msg43142404
# https://www.facebook.com/taras.siruy.3/posts/142928479953045 right share
# https://www.facebook.com/taras.siruy.3/posts/140383330207560 right share
# https://www.facebook.com/taras.siruy.3/posts/140809616831598 right share
# https://www.facebook.com/taras.siruy.3/posts/142206220025271 right share
# https://www.facebook.com/taras.siruy.3/posts/141560540089839 right share
# 有效分享数： 5 有效评论数： 0
# https://bitcointalk.org/index.php?topic=4778587.msg43142404#msg43142404 5 0 帖子分享有效
# 正在检查第3个帖子......
# 当前检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43143446#msg43143446
# ...

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }







url = 'https://bitcointalk.org/index.php?topic=4778587.msg43623936#msg43623936'
#thread_number = url.split('#')[-1]
data = requests.get(url,headers = header,verify=False,proxies = proxie)
soup = BeautifulSoup(data.text,'html.parser')
reply = soup.find(attrs={'href':url}).parent.parent.parent.parent
print(str(reply).lower())

links = '\n'.join(set(re.findall('href="(.+?)"',str(reply))))
#print(links)

c

name = 'vijeeq'
twitter_reg = 'https://.*?twitter.com/'+name+'/status/\d+'

fb_share = 'https://\w{3}.facebook.com/[^NAUSOFFICIAL\n]+?/posts/\d+'
#fb_comment = '"(https://\w{3}.facebook.com/NAUSOFFICIAL/posts/.+?comment_id.*?)"'
fb_comment = '(https://\w{3}.facebook.com/NAUSOFFICIAL/posts/.+?comment_id=.*?comment_tracking=.*?D)|(https://\w{3}.facebook.com/NAUSOFFICIAL/posts/.+?comment_id.*?)' 

share_url = set(re.findall(fb_share,links))
comment = set(re.findall(fb_comment,links))
twitter = set(re.findall(twitter_reg,links))

a = 0
for i in share_url:
    a += 1
    print(a,i)
print(len(share_url))

print('==================')

for i in comment:
    print(i)
print(len(comment))

print('==================')

for i in twitter:
    print(i)
print(len(twitter))
# Out:
# <td class="td_headerandpost" height="100%" style="padding: 2px;" valign="top" width="85%">
# <table border="0" width="100%"><tr>
# <td valign="middle"><a href="https://bitcointalk.org/index.php?topic=4778587.msg43623936#msg43623936"><img alt="" border="0" src="https://bitcointalk.org/themes/custom1/images/post/xx.gif"/></a></td>
# <td valign="middle">
# <div class="subject" id="subject_43623936" style="font-weight: bold;">
# <a href="https://bitcointalk.org/index.php?topic=4778587.msg43623936#msg43623936">re: [bounty]  🚀🚀🚀naus | a blockchain based social network by tencent team🚀🚀🚀</a>
# </div>
# <div class="smalltext"><span class="edited" title="last edit: september 02, 2018, 07:41:44 am by vinjan">august 07, 2018, 04:07:33 am</span></div></td>
# ...

# %%
    
    
fb_share = 'https://\w{3}.facebook.com/[^NAUSOFFICIAL]+?/posts/\d+'



fb_comment = '"(https://web.facebook.com/NAUSOFFICIAL/posts/.+?comment_id.*?)"'

share_url = set(re.findall(fb_share,links))
comment = set(re.findall(fb_comment,links,re.S))

if len(comment) == 0:
    print('yes')
    fb_comment = '"(https://www.facebook.com/NAUSOFFICIAL/posts/.+?comment_id=.+?D)"' 
    comment = set(re.findall(fb_comment,str(reply),re.S))
    
for i in share_url:
    print(i)
print(len(share_url))
print('==================')
for i in comment:
    print(i)
print(len(comment))

'''
options = webdriver.ChromeOptions()
options.add_argument('--proxy-server=http://127.0.0.1:1080')  
options.add_experimental_option('prefs',prefs)
driver = webdriver.Chrome(chrome_options=options)


url = 'https://www.facebook.com/taras.siruy.3/posts/140383330207560'

username = '452070961@qq.com'
password = 'Jamie8449671'
    
driver.get('https://www.facebook.com/')
driver.find_element_by_id('email').send_keys(username)
driver.find_element_by_id('pass').send_keys(password)
driver.find_element_by_id('loginbutton').submit()
driver.implicitly_wait(10)

driver.get(url)
content = driver.find_element_by_css_selector('div._1dwg._1w_m._q7o').text
time.sleep(randint(1,10))
print(content)
'''

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)


def check_tweet(url,name):
    print('当前twitter用户名:{}\n检查BTTurl:{}'.format(name,url))
    
    proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

    header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

    prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }

    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    
    username = ''
    password = ''
    
    driver.get('https://www.facebook.com/')
    driver.find_element_by_id('email').send_keys(username)
    driver.find_element_by_id('pass').send_keys(password)
    driver.find_element_by_id('loginbutton').submit()
    driver.implicitly_wait(10)
    
    
    
    with open('tweetscheck0904.csv','a',encoding='utf-8') as w:
        number = 0 
        try:
            thread_number = url.split('#')[-1]
            data = requests.get(url,headers = header,verify=False,proxies = proxie)
            soup = BeautifulSoup(data.text,'html.parser')
            reply = soup.find(attrs={'name':thread_number}).parent
            content = reply.select('.post')
            twitter_reg = 'https://twitter.com/'+name+'/status/\d+'
            tweet_url = set(re.findall(twitter_reg,str(content)))
            
        except Exception as error:
            print(url,'用户提供的链接有问题',error)
            status = '用户提供的帖子链接有问题'
        else:
            
            if len(tweet_url) == 0:
                print(url,'当前帖子无推文链接')
                status = '当前帖子无推文链接'
            else:   

                for i in tweet_url:
                    try:
                        driver.get(i)
                        content = driver.find_element_by_css_selector('.permalink-inner.permalink-tweet-container').text
                        time.sleep(randint(1,10))
                    except:
                        pass
                        print(i,'推文链接有问题')
                    else:
                        if 'NAUS' or 'NausGlobal' in content:
                            print(i,'right tweet')
                            number += 1
                        else:
                            print(i,'wrong tweet')
                        
                status = '当前帖子推文链接有效'
                print('有效推文数：',number)
        driver.quit()        
        print(url,number,status)
        w.write('{},{},{}\n'.format(url,number,status))
        


url =  'https://bitcointalk.org/index.php?topic=4778587.msg43147048#msg43147048'
name = 'Maria Christina Delan'
check_tweet(url,name)
# Out:
# 当前twitter用户名:Maria Christina Delan
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43147048#msg43147048
# https://bitcointalk.org/index.php?topic=4778587.msg43147048#msg43147048 当前帖子无推文链接
# https://bitcointalk.org/index.php?topic=4778587.msg43147048#msg43147048 0 当前帖子无推文链接

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)


def check_tweet(url,name):
    print('当前twitter用户名:{}\n检查BTTurl:{}'.format(name,url))
    
    proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

    header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

    prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }

    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    
    with open('tweetscheck0903.csv','a',encoding='utf-8') as w:
        number = 0 
        try:
            
            data = requests.get(url,headers = header,verify=False,proxies = proxie)
            soup = BeautifulSoup(data.text,'html.parser')
            reply = soup.find(attrs={'href':url}).parent.parent.parent.parent
            content = reply.select('.post')
            twitter_reg = 'https://.*?twitter.com/'+name+'/status/\d+'
            tweet_url = set(re.findall(twitter_reg,str(content)))
            
            #reply = soup.find(attrs={'href':url}).parent
        except:
            #print(url,'用户提供的链接有问题')
            status = '用户提供的帖子链接有问题'
        else:
            
            if len(tweet_url) == 0:
                #print(url,'当前帖子无推文链接')
                status = '当前帖子无推文链接'
            else:   

                for i in tweet_url:
                    try:
                        driver.get(i)
                        content = driver.find_element_by_css_selector('.permalink-inner.permalink-tweet-container').text
                        time.sleep(randint(1,10))
                    except:
                        pass
                        #print(i,'推文链接有问题')
                        status = '推文链接有问题'
                    else:
                        if 'NAUS' or 'NausGlobal' in content:
                            #print(i,'right tweet')
                            number += 1
                            status = '推文内容正确'
                        else:
                            #print(i,'wrong tweet')
                            status = '推文内容错误'
                        
                
                #print('有效推文数：',number)
                driver.quit()
        print(url,number,status)
        

url = 'https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218'
name = 'DevanNaratama'
check_tweet(url,name)
# Out:
# 当前twitter用户名:DevanNaratama
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218
# https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218 20 推文内容正确

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import time
from random import randint

from requests.packages.urllib3.exceptions import InsecureRequestWarning 

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)


def check_tweet(url,name):
    print('当前twitter用户名:{}\n检查BTTurl:{}'.format(name,url))
    
    proxie = {
        'http':'http://127.0.0.1:1080',
        'https':'https://127.0.0.1:1080'}

    header = { 
        'User-Agent' : 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36',
        }

    prefs = {'profile.default_content_setting_values':
                {
                'notifications':2
                }
        }

    options = webdriver.ChromeOptions()
    options.add_argument('--proxy-server=http://127.0.0.1:1080')  
    options.add_experimental_option('prefs',prefs)
    driver = webdriver.Chrome(chrome_options=options)
    
    with open('tweetscheck0911.csv','a',encoding='utf-8') as w:
        number = 0 
        try:
            data = requests.get(url,headers = header,verify=False,proxies = proxie)
            soup = BeautifulSoup(data.text,'html.parser')
            reply = soup.find(attrs={'href':url}).parent.parent.parent.parent
            content = reply.select('.post')
            twitter_reg = 'https://.*?twitter.com/'+name+'/status/\d+'
            tweet_url = set(re.findall(twitter_reg,str(content),re.I))
        except:
            #print(url,'用户提供的链接有问题')
            status = '用户提供的帖子链接有问题'
        else:
            
            if len(tweet_url) == 0:
                #print(url,'当前帖子无推文链接')
                status = '当前帖子无推文链接'
            else:   

                for i in tweet_url:
                    try:
                        driver.get(i)
                        content = driver.find_element_by_css_selector('.permalink-inner.permalink-tweet-container').text
                        time.sleep(randint(10,20))
                    except:
                        pass
                        #print(i,'推文链接有问题')
                        status = '当前推文链接有问题'
                    else:
                        if 'NAUS' or 'NausGlobal' in content:
                            #print(i,'right tweet')
                            status = '当前推文有效'
                            number += 1
                        else:
                            #print(i,'wrong tweet')
                            status = '当前推文无效'
                        
                
            
                driver.quit()
        print(url,number,status)
        
        



    

url = 'https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218'
name = 'devannaratama'
check_tweet(url,name)
# Out:
# 当前twitter用户名:devannaratama
# 检查BTTurl:https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218
# https://bitcointalk.org/index.php?topic=4778587.msg43209218#msg43209218 20 当前推文有效
